# %%
import pandas as pd
import requests
import math
from thefuzz import fuzz
import csv
import os
import re
import time
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
API_KEY = os.getenv("GOOGLE_API_KEY")
if(API_KEY is None):
    raise ValueError("No API key found. Please set the GOOGLE_API_KEY environment variable.")
print("Using API Key:", API_KEY)
#  ตั้งค่าว่าจะใช้ข้อมูลจริงจาก API หรือข้อมูลจำลอง
#    - True:  จะเรียก API จริง (ต้องใส่ API_KEY และมีอินเทอร์เน็ต)
#    - False: จะใช้ข้อมูลจำลองในโค้ด (สำหรับทดสอบโดยไม่ใช้ API Key)
USE_REAL_API = True
# -----------------------------

# เกณฑ์คะแนน
SCORE_THRESHOLD_OK = 9      # ≥9 = เชื่อว่าถูก (ตรง)
SCORE_THRESHOLD_REVIEW = 7  # 7-8 = ต้องตรวจซ้ำ (ไม่แน่ใจ)
# Out:
# Using API Key: AIzaSyCzHeJ4ed7vQBAoPpgQVFyFx0IEAeEKds0

# %%
def get_place_details_real(query, api_key):
    """ฟังก์ชันสำหรับเรียก Google Places API จริง"""
    time.sleep(0.2)  # หน่วงเวลา 200ms เพื่อหลีกเลี่ยงการเรียก API รวดเร็วเกินไป
    url = "https://places.googleapis.com/v1/places:searchText"
    headers = {
        'Content-Type': 'application/json',
        'X-Goog-Api-Key': api_key,
        'X-Goog-FieldMask': 'places.id,places.displayName,places.formattedAddress,places.types,places.location,places.rating,places.userRatingCount,places.googleMapsUri'
    }
    data = {
        "textQuery": query, 
        "languageCode": "th",
        "regionCode": "TH",
        }
    try:
        response = requests.post(url, json=data, headers=headers)
        response.raise_for_status()
        return response.json().get('places', [])
    except requests.exceptions.RequestException as e:
        print(f"เกิดข้อผิดพลาดในการเรียก API สำหรับคำค้น '{query}': {e}")
        return []

# %%
def get_place_details_mock(query):
    """ฟังก์ชันสำหรับข้อมูลจำลอง (Mock Data) เพื่อการทดสอบ"""
    mock_responses = {
        "เสาหินบะซอลต์ นางรอง บุรีรัมย์ ประเทศไทย": [{
            "id": "ChIJ-e2a_wBwXDARWp999999999", 
            "types": ["tourist_attraction", "point_of_interest"],
            "formattedAddress": "บ้านโคกมะค่าโหรน หมู่ 12 ต.สะเดา อ.นางรอง จ.บุรีรัมย์",
            "location": {"latitude": 14.58313, "longitude": 102.80535}, 
            "rating": 4.5,
            "googleMapsUri": "https://maps.google.com/?cid=12345", 
            "userRatingCount": 150,
            "displayName": {"text": "เสาหินบะซอลต์ ภูเขาไฟ", "languageCode": "th"}
        }],
        "วัดเจริญสุขารามวรวิหาร บางคนที สมุทรสงคราม ประเทศไทย": [{
            "id": "ChIJH-mplqGR4jARs-Vf9-Vf9-V", 
            "types": ["tourist_attraction", "place_of_worship"],
            "formattedAddress": "ต.บางนกแขวก อ.บางคนที จ.สมุทรสงคราม 75120",
            "location": {"latitude": 13.50111, "longitude": 99.92706},
            "rating": 4.6,
            "googleMapsUri": "https://maps.google.com/?cid=67890",
            "userRatingCount": 500,
            "displayName": {"text": "วัดเจริญสุขารามวรวิหาร", "languageCode": "th"}
        }]
    }
    return mock_responses.get(query, [])

# %%
def thai_digits_to_arabic(s: str) -> str:
    """แปลงเลขไทยในสตริงเป็นเลขอารบิก"""
    if not isinstance(s, str): return s
    map_dict = {"๐": "0", "๑": "1", "๒": "2", "๓": "3", "๔": "4", "๕": "5", "๖": "6", "๗": "7", "๘": "8", "๙": "9"}
    return s.translate(str.maketrans(map_dict))

def normalize_name(s: str) -> str:
    """ทำความสะอาดและทำให้ชื่อเป็นมาตรฐานสำหรับการเปรียบเทียบ"""
    if not isinstance(s, str): return ""
    text = thai_digits_to_arabic(s.lower().strip())
    text = re.sub(r'[()【】\[\]{}]', ' ', text)
    # ตัดคำบ่งชี้การปกครอง/คำก่อกวนทั่วไป
    admin_terms = r'\b(จังหวัด|จ\.|อำเภอ|อ\.|ตำบล|ต\.|เทศบาล|เขต|แขวง|สาขา|จุดชมวิว)\b'
    text = re.sub(admin_terms, '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
KEYWORD_TYPE_RULES = [
    (re.compile(r'\b(อุทยาน|วนอุทยาน|อช\.|อช|อุทยานแห่งชาติ|ดอย|ภู|เขา|ถ้ำ|น้ำตก|บ่อน้ำพุร้อน|บ่อน้ำพุ)', re.IGNORECASE), "park"),
    (re.compile(r'\b(พิพิธภัณฑ์|พิพิธภัณฑ์สัตว์น้ำ)', re.IGNORECASE), "museum"),
    (re.compile(r'\b(พิพิธภัณฑ์สัตว์น้ำ|อควาเรียม|aquarium)', re.IGNORECASE), "aquarium"),
    (re.compile(r'\b(สวนสัตว์|ซู)', re.IGNORECASE), "zoo"),
    (re.compile(r'\b(ห้าง|มอลล์|พลาซ่า|plaza|mall|shopping)', re.IGNORECASE), "shopping_mall"),
    (re.compile(r'\b(ตลาด)', re.IGNORECASE), "market"),
    (re.compile(r'\b(วัด|เจดีย์|เจติยสถาน|สำนักสงฆ์|พระธาตุ)', re.IGNORECASE), "place_of_worship"),
    (re.compile(r'\b(มัสยิด)\b', re.IGNORECASE), "mosque"),
    (re.compile(r'\b(โบสถ์|คริสตจักร)\b', re.IGNORECASE), "church"),
    (re.compile(r'\b(ที่พัก|รีสอร์ท|โรงแรม|โฮสเทล|โฮมสเตย์|homestay|resort|hotel|hostel)', re.IGNORECASE), "lodging"),
    (re.compile(r'\b(ร้านอาหาร|อาหาร|restaurant)', re.IGNORECASE), "restaurant"),
    (re.compile(r'\b(คาเฟ่|กาแฟ|cafe|coffee)', re.IGNORECASE), "cafe"),
]
def pick_included_type(text: str, default_type="tourist_attraction") -> str:
    """เลือกประเภทของสถานที่จาก Keyword ในชื่อ"""
    if not isinstance(text, str): return default_type
    for pattern, type_name in KEYWORD_TYPE_RULES:
        if pattern.search(text):
            return type_name
    return default_type

# %%
def haversine_meters(lat1, lon1, lat2, lon2):
    """คำนวณระยะทางเป็น 'เมตร'"""
    R = 6371000  # รัศมีโลกในหน่วยเมตร
    if any(v is None for v in [lat1, lon1, lat2, lon2]): return float('inf')
    to_rad = lambda d: d * math.pi / 180
    d_lat, d_lng = to_rad(lat2 - lat1), to_rad(lon2 - lon1)
    la1, la2 = to_rad(lat1), to_rad(lat2)
    a = math.sin(d_lat/2)**2 + math.cos(la1) * math.cos(la2) * math.sin(d_lng/2)**2
    return 2 * R * math.asin(math.sqrt(a))

# %%
def score_candidate(src_row, cand_place):
    """ให้คะแนนสถานที่ที่ได้จาก API เทียบกับข้อมูลตั้งต้น"""
    score = 0
    reasons = []

    # --- ให้คะแนนจากระยะทาง ---
    distance = haversine_meters(src_row['latitude'], src_row['longitude'], cand_place['location']['latitude'], cand_place['location']['longitude'])
    if distance < 200:
        score += 5
        reasons.append(f"distance<200m (+5)")
    elif distance < 500:
        score += 4
        reasons.append(f"distance<500m (+4)")
    elif distance < 1000:
        score += 3
        reasons.append(f"distance<1km (+3)")
    elif distance < 5000:
        score += 2
        reasons.append(f"distance<5km (+2)")
    elif distance < 10000:
        score += 1
        reasons.append(f"distance<10km (+1)")
    else:
        reasons.append(f"distance>=10km (+0)")

    # --- ให้คะแนนจากความคล้ายของชื่อ ---
    # ใช้ thefuzz ซึ่งแม่นยำกว่า token overlap
    norm_src_name = normalize_name(src_row['name'])
    norm_cand_name = normalize_name(cand_place['displayName']['text'])
    sim = fuzz.ratio(norm_src_name, norm_cand_name) / 100.0  # similarity 0..1
    
    if sim >= 0.92:
        score += 4
        reasons.append(f"name_sim>0.92 (+4)")
    elif sim >= 0.85:
        score += 3
        reasons.append(f"name_sim>0.85 (+3)")
    elif sim >= 0.75:
        score += 2
        reasons.append(f"name_sim>0.75 (+2)")
    elif sim >= 0.6:
        score += 1
        reasons.append(f"name_sim>0.6 (+1)")
    else:
        reasons.append(f"name_sim<=0.6 (+0)")

    # --- ให้คะแนนจากอำเภอที่ตรงกัน ---
    # หมายเหตุ: Google API ไม่ได้คืนค่าอำเภอมาตรงๆ เราอาจต้องดึงจาก formattedAddress
    src_district = src_row.get('district')
    cand_address = cand_place.get('formattedAddress', '')
    if src_district and src_district in cand_address:
        score += 2
        reasons.append(f"district_match (+2)")

    # --- (Optional) ให้คะแนนจากประเภทที่ตรงกัน ---
    expected_type = pick_included_type(src_row['name'])
    if expected_type != "tourist_attraction" and expected_type in cand_place.get('types', []):
        score += 2
        reasons.append(f"type_match:'{expected_type}' (+2)")

    return {"score": score, "reasons": ", ".join(reasons), "distance_m": distance}

# %%
def best_match_for_row(src_row, places):
    """เลือกผลลัพธ์ที่ดีที่สุดจากรายการสถานที่ที่ได้จาก API"""
    best_score = -1
    best_place = None
    best_reasons = ""
    best_distance = float('inf')

    for place in places:
        result = score_candidate(src_row, place)
        if result['score'] > best_score or (result['score'] == best_score and result['distance_m'] < best_distance):
            best_score = result['score']
            best_place = place
            best_reasons = result['reasons']
            best_distance = result['distance_m']

    return best_place, best_score, best_reasons, best_distance

# %%
def main():
    input_filename = 'prePlacesData.csv'
    output_filename = 'postPlacesFetch.csv'

    try:
        df_pre = pd.read_csv(input_filename)
    except FileNotFoundError:
        print(f"ข้อผิดพลาด: ไม่พบไฟล์ '{input_filename}'")
        return

    fieldnames = [
        'original_index', 'match_result', 'score', 'score_reasons', 'distance_m',
        'textQuery', 'expected_type', 'api_name', 'api_formattedAddress',
        'api_location', 'api_rating', 'api_userRatingCount', 'api_types',
        'api_placeId', 'api_URI', 'original_detail'
    ]

    with open(output_filename, 'w', newline='', encoding='utf-8-sig') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for index, row in df_pre.iterrows():
            print(f"กำลังประมวลผล index {row['idx']}: {row['name']}...")
            
            if USE_REAL_API:
                places_found = get_place_details_real(row['textQuery'], API_KEY)
            else:
                places_found = get_place_details_mock(row['textQuery'])
            
              
            if places_found:
                top_result, top_score, top_reasons, top_distance = best_match_for_row(row, places_found)
            
            
            # ตัดสินผลลัพธ์จากคะแนน
            if top_score >= SCORE_THRESHOLD_OK:
                match_result = "ตรง"
            elif top_score >= SCORE_THRESHOLD_REVIEW:
                match_result = "ไม่แน่ใจ (ต้องตรวจซ้ำ)"
            else:
                match_result = "ไม่ตรง"

            result_row = {
                'original_index': row['idx'],
                'match_result': match_result,
                'score': top_score,
                'score_reasons': top_reasons,
                'distance_m': round(top_distance, 2),
                'textQuery': row['textQuery'],
                'expected_type': pick_included_type(row['name']),
                'api_name': top_result.get('displayName', {}).get('text'),
                'api_formattedAddress': top_result.get('formattedAddress'),
                'api_location': top_result.get('location'),
                'api_rating': top_result.get('rating'),
                'api_userRatingCount': top_result.get('userRatingCount'),
                'api_URI': top_result.get('googleMapsUri'),
                'api_types': ", ".join(top_result.get('types', [])),
                'api_placeId': top_result.get('id'),
                'original_detail': row.get('detail', '')
            }
            writer.writerow(result_row)

    print(f"\nประมวลผลเสร็จสิ้น! บันทึกผลลัพธ์ลงในไฟล์ '{output_filename}'")
    if os.path.exists(output_filename):
        print("\nตัวอย่างข้อมูลจากไฟล์ผลลัพธ์:")
        print(pd.read_csv(output_filename).head())

# %%
if __name__ == '__main__':
    main()
# Out:
# กำลังประมวลผล index 0: เสาหินบะซอลต์...
# กำลังประมวลผล index 1: อ่างเก็บน้ำลำพอก...
# กำลังประมวลผล index 3: กลุ่มสตรีทอผ้าบ้านท่ากระจาย...
# กำลังประมวลผล index 4: องค์ศรีสุขคเณศ...
# กำลังประมวลผล index 5: พัทยา ดอลฟินาเรียม...
# กำลังประมวลผล index 6: เกาะนกเภา...
# กำลังประมวลผล index 7: สวนภูทิพย์ธารา...
# กำลังประมวลผล index 8: ผาเหนือเมฆ...
# กำลังประมวลผล index 9:  ตลาดต้าน้ำโบราณบ้านต้นตาล...
# กำลังประมวลผล index 10: Miracle of Natural...
# กำลังประมวลผล index 11: ศูนย์การเรียนรู้ภูเพียงโมเดล   รักษ์ป่าน่าน...
# กำลังประมวลผล index 12: เกาะกวาง...
# กำลังประมวลผล index 13: เมืองเก่ากันตัง...
# กำลังประมวลผล index 14: ตลาดลงเล...
# กำลังประมวลผล index 15: วัดหน้าวัว ...
# กำลังประมวลผล index 16: พิพิธภัณฑ์สถานแห่งพระพุทธบาท...
# กำลังประมวลผล index 17: โป่งแยง จังเกิ้ล โคสเตอร์ ซิปไลน์...
# กำลังประมวลผล index 18: น้ำตกตรอกนอง...
# กำลังประมวลผล index 19: Central Phitsanulok...
# กำลังประมวลผล index 20: วัดถ้ำตับเตา...
# กำลังประมวลผล index 21: วัดแสงแก้วโพธิญาณ...
# กำลังประมวลผล index 22: วัดเวียง...
# กำลังประมวลผล index 23: ตลาดน้ำประชารัฐบางใบไม้...
# กำลังประมวลผล index 24: เจดีย์บ้านหัวแหลม...
# กำลังประมวลผล index 25: ตลาดร่มพญาไม้...
# กำลังประมวลผล index 26: ศูนย์ส่งเสริมเทคโนโลยีการเกษตรด้านแมลงเศรษฐกิจจังหวัดเชียงใหม่...
# กำลังประมวลผล index 27: ตลาดนัดชุมชนบ่อยาง...
# กำลังประมวลผล index 28: ตลาดริมเมย...
# กำลังประมวลผล index 29: พิพิธภัณฑ์ไม้สัก    ...
# กำลังประมวลผล index 30: วัดศาลาแดง...
# กำลังประมวลผล index 31: พระที่นั่งเพนียด...
# กำลังประมวลผล index 32: เรือนจำชั่วคราวเฟื่องฟ้า...
# กำลังประมวลผล index 33: อุทยานแห่งชาติน้ำตกบัวตอง น้ำพุเจ็ดสี...
# กำลังประมวลผล index 34: สวนสิทธิกร บ้านห้วยสำราญ...
# กำลังประมวลผล index 35: วัดวังชัย...
# กำลังประมวลผล index 36: กองหินเพลิง...
# กำลังประมวลผล index 37: Mountain Coffee at Zoo ...
# กำลังประมวลผล index 38: ทุ่งปอเทือง ทุ่งทานตะวัน ...
# กำลังประมวลผล index 39: เนเจอร์วอล์คเวย์...
# กำลังประมวลผล index 40: พิพิธภัณฑ์ศิลป์แผ่นดิน...
# กำลังประมวลผล index 41: ม่อนแกะ ฟาร์มสเตย์...
# กำลังประมวลผล index 42: ตลาดหัวปลี...
# กำลังประมวลผล index 43: โรงบ่ม ริมน้ำน่าน บ้านดอนตัน...
# กำลังประมวลผล index 44: พิพิธภัณฑสถานแห่งชาติสตูล (คฤหาสน์กูเด็น)...
# กำลังประมวลผล index 45: คลองสระแก้ว...
# กำลังประมวลผล index 46: คลองหรูด คลองน้ำใส...
# กำลังประมวลผล index 47: พระโพธิสัตว์เจ้าแม่กวนอิม...
# กำลังประมวลผล index 48: ชุมชนเกาะลัดอีแท่น...
# กำลังประมวลผล index 49: วัดธาราทิพย์ชัยประดิษฐ์...
# กำลังประมวลผล index 50: ตลาดทรัพย์สิน (ท่าไข่)...
# กำลังประมวลผล index 51: โครงการคชอาณาจักร จังหวัดสุรินทร์...
# กำลังประมวลผล index 52: ตลาดน้ำ 4000 ปี ไนท์บาร์ซ่า...
# กำลังประมวลผล index 53: บ้านโบราณ ณ สมุย...
# กำลังประมวลผล index 54: วัน นิมมาน...
# กำลังประมวลผล index 55: วัดเขาโปร่งใต้...
# กำลังประมวลผล index 56: ไร่สตรอเบอร์รี่ไผ่สีทอง ...
# กำลังประมวลผล index 57: สวนแม่หม่อนจากมัลเบอรร์รี่...
# กำลังประมวลผล index 58: วัน นิมมาน ...
# กำลังประมวลผล index 59: กาดบ้านฮ่อ...
# กำลังประมวลผล index 60: วัดสันป่าสักวรอุไรธรรมมาราม...
# กำลังประมวลผล index 61: น้ำตก เขานางหย่อง...
# กำลังประมวลผล index 62: สวนไดโนเสาร์พัทยา ...
# กำลังประมวลผล index 63: วัดโตนด...
# กำลังประมวลผล index 64: Kyoto Shi Cafe...
# กำลังประมวลผล index 65: สวนมะพร้าวลุงบูรณ์...
# กำลังประมวลผล index 66: ชุมชนย่านเมืองเก่าริมน้ำเพชรบุรี...
# กำลังประมวลผล index 67: จุดชมวิวบ้านขอบด้ง...
# กำลังประมวลผล index 68: โนราโรงครู วัดท่าแค...
# กำลังประมวลผล index 69: หมู่บ้านม้งแม่ขุนวาก...
# กำลังประมวลผล index 70: เกรทแอนด์แกรนด์ สวีท เดสติเนชั่น...
# กำลังประมวลผล index 71: ชุมชนบ้านน้ำราบ...
# กำลังประมวลผล index 72: ป่าสาคู...
# กำลังประมวลผล index 73: ถนนนางงาม...
# กำลังประมวลผล index 74: วัดท่าหลวง พระอารามหลวง...
# กำลังประมวลผล index 75: อุทยานแห่งชาติตะรุเตา...
# กำลังประมวลผล index 76: หมู่บ้านอนุรักษ์ควายไทย...
# กำลังประมวลผล index 77: โครงการสระเก็บน้ำพระราม 9...
# กำลังประมวลผล index 78: วัดตำหนัก...
# กำลังประมวลผล index 79: วัดพะโคะ (วัดราชประดิษฐาน)...
# กำลังประมวลผล index 80: พระธาตุปูแจ...
# กำลังประมวลผล index 81: เขาพระบาท...
# กำลังประมวลผล index 82: อุทยานแห่งชาติภูสวนทราย...
# กำลังประมวลผล index 83: สวนสาธารณะและสวนพฤกษชาติ ศรีนครเขื่อนขันธ์...
# กำลังประมวลผล index 84: น้ำตกเขาคราม...
# กำลังประมวลผล index 85: เอกชัย กอล์ฟ แอนด์ คันทรี คลับ...
# กำลังประมวลผล index 86: พระปรางค์สามยอด...
# กำลังประมวลผล index 87: ปราสาทบ้านบุ...
# กำลังประมวลผล index 88: อุทยานแห่งชาติเขาพระวิหาร...
# กำลังประมวลผล index 89: ตลาด 100 ปี ศาลเจ้าโรงทอง...
# กำลังประมวลผล index 90: บึงตะโก้...
# กำลังประมวลผล index 91: สนามมวยเวทีราชดำเนิน...
# กำลังประมวลผล index 92: สะพานมิตรภาพไทย ลาว  ...
# กำลังประมวลผล index 93: เมืองโบราณดงละคร...
# กำลังประมวลผล index 94: กู่ประภาชัย ...
# กำลังประมวลผล index 95: อุทยานแห่งชาติเวียงโกศัย  ...
# กำลังประมวลผล index 96: วัดพระธาตุพระลอ  ...
# กำลังประมวลผล index 97: พระธาตุบังพวน...
# กำลังประมวลผล index 98: วิสาหกิจชุมชนบ้านทะเลนอกโฮมสเตย์...
# กำลังประมวลผล index 99: อุทยานแห่งชาติหมู่เกาะระนอง...
# กำลังประมวลผล index 100: โครงการส่งเสริมการทอผ้าไหมแพรวา บ้านโพน มูลนิธิส่งเสริมศิลปาชีพ ในสมเด็จพระนางเจ้าสิริกิติ์พระบรมราชินีนาถ...
# กำลังประมวลผล index 101: กลุ่มเครื่องปั้นดินเผาเขียนสีลายบ้านเชียง...
# กำลังประมวลผล index 102: ปราสาทเขาน้อยสีชมพู...
# กำลังประมวลผล index 103: พระเจดีย์หลวง...
# กำลังประมวลผล index 104: ชุมชนบ้านเกาะแรต...
# กำลังประมวลผล index 105: สวนสมเด็จพระศรีนครินทร์ ร้อยเอ็ด...
# กำลังประมวลผล index 106: วัดถ้ำพุหว้า...
# กำลังประมวลผล index 107: คลองร้อยสาย...
# กำลังประมวลผล index 108: โคโรฟิลด์...
# กำลังประมวลผล index 109: เขื่อนห้วยขนุน...
# กำลังประมวลผล index 110: ล่องแก่งลำน้ำเข็ก...
# กำลังประมวลผล index 111: วัดต่อแพ...
# กำลังประมวลผล index 112: ตลาดธนบุรี สนามหลวง 2...
# กำลังประมวลผล index 113: วัดถ้ำพระโพธิสัตว์...
# กำลังประมวลผล index 114: สยามนิรมิต...
# กำลังประมวลผล index 115: หาดนางรอง...
# กำลังประมวลผล index 116: เรือรบหลวงจักรีนฤเบศร์...
# กำลังประมวลผล index 117: ถ้ำน้ำมุด...
# กำลังประมวลผล index 118: อุทยานแห่งชาติเฉลิมรัตนโกสินทร์...
# กำลังประมวลผล index 119: วัดพระธาตุวาโย...
# กำลังประมวลผล index 120: น้ำตกซำไทร...
# กำลังประมวลผล index 121: วัดนครธรรม...
# กำลังประมวลผล index 122: วังยะหริ่ง...
# กำลังประมวลผล index 123: วัดธรรมจักรเสมาราม...
# กำลังประมวลผล index 124: กลุ่มผลิตภัณฑ์ไม้ไผ่ บ้านโง้ง บ้านต้น...
# กำลังประมวลผล index 125: พิพิธภัณฑ์เมืองอุดรธานี...
# กำลังประมวลผล index 126: ชุมชนท่องเที่ยวทุ่งหว้า...
# กำลังประมวลผล index 127: อุทยานแห่งชาติหาดเจ้าไหม...
# กำลังประมวลผล index 128: น้ำตกห้วยเกษียร...
# กำลังประมวลผล index 129: ปราสาทบ้านน้อย...
# กำลังประมวลผล index 130: พิพิธภัณฑสถานแห่งชาติอู่ทอง...
# กำลังประมวลผล index 131: กลุ่มแม่บ้านเกษตรกรทอผ้าไหมขิดบ้านศรีชมชื่น ...
# กำลังประมวลผล index 132: ศูนย์ศิลปาชีพบ้านกุดนาขาม...
# กำลังประมวลผล index 133: ไร่ บี เอ็น...
# กำลังประมวลผล index 134: น้ำตกลาดเตย...
# กำลังประมวลผล index 135: ศาลสมเด็จพระเจ้าตากสินมหาราช...
# กำลังประมวลผล index 136: วัดคูหาสวรรค์...
# กำลังประมวลผล index 137: วนอุทยานดอยเวียงแก้ว...
# กำลังประมวลผล index 138: เขาพ่อตาโชงโดง...
# กำลังประมวลผล index 139: กุฏิทรงไทยวัดวังตะวันตก...
# กำลังประมวลผล index 140: สวนโกโก้ ...
# กำลังประมวลผล index 141: วัดพระนอน...
# กำลังประมวลผล index 142: วัดพระศรีรัตนมหาธาตุ...
# กำลังประมวลผล index 143: วัดคูหาภิมุข ...
# กำลังประมวลผล index 144: อ่าวปะตก...
# กำลังประมวลผล index 145: อุทยานแห่งชาติภูเรือ...
# กำลังประมวลผล index 146: วัดมหาพุทธาราม...
# กำลังประมวลผล index 147: สวนรุกขชาติป่าชายเลนคลองละอุ่น...
# กำลังประมวลผล index 148: อุทยานวังมัจฉา...
# กำลังประมวลผล index 149: เขาค้อทะเลภู...
# กำลังประมวลผล index 150: ตลาดเก่าเมืองสุพรรณฯ ...
# กำลังประมวลผล index 151: บ่อน้ำร้อน สวนสาธารณะรักษะวาริน...
# กำลังประมวลผล index 152: วัดจะทิ้งพระ...
# กำลังประมวลผล index 153: อุทยานรังสรรค์นวัตกรรมอวกาศ...
# กำลังประมวลผล index 154: บ่อน้ำศักดิ์สิทธิ์ วัดแหลมบ่อท่อ...
# กำลังประมวลผล index 155: ปราสาทพระธาตุนารายณ์เจงเวง...
# กำลังประมวลผล index 156: วนอุทยานพนมสวาย...
# กำลังประมวลผล index 157: วัดชุมพลนิกายารามราชวรวิหาร...
# กำลังประมวลผล index 158: ถ้ำแก้วโครำ...
# กำลังประมวลผล index 159: น้ำตกทับซุง...
# กำลังประมวลผล index 160: สวนน้ำทะเลเลย...
# กำลังประมวลผล index 161: ธารน้ำร้อนบ่อคลึง...
# กำลังประมวลผล index 162: ตลาดนัดจตุจักรพระราม 3...
# กำลังประมวลผล index 163: วัดสุทัศน์เทพวราราม ราชวรมหาวิหาร...
# กำลังประมวลผล index 164: พลับพลาวิหารแดง...
# กำลังประมวลผล index 165: วัดราษฎร์ศรัทธากะยาราม...
# กำลังประมวลผล index 166: สระแก้ว สระขวัญ...
# กำลังประมวลผล index 167: บ้านท่านขุนรัฐวุฒิวิจารณ์...
# กำลังประมวลผล index 168: คอนโดนกนางแอ่น...
# กำลังประมวลผล index 169: อนุสาวรีย์พระยาศรีสุนทรโวหาร (น้อย อาจารยางกูร)...
# กำลังประมวลผล index 170: น้ำตกไทรคู่...
# กำลังประมวลผล index 171: กลุ่มผลิตน้ำมันงาบ้านสบสอย แม่ฮ่องสอน...
# กำลังประมวลผล index 172: สะพานมิตรภาพไทย ลาว แห่งที่ 3    ...
# กำลังประมวลผล index 173: วัดพระธาตุจอมจ้อ...
# กำลังประมวลผล index 174: ถ้ำเพชร...
# กำลังประมวลผล index 175: เกาะตะละเบ็ง...
# กำลังประมวลผล index 176: วัดพระธาตุจอมหมอกแก้ว...
# กำลังประมวลผล index 177: วัดพระธาตุดอยเขาควาย ...
# กำลังประมวลผล index 178: ศูนย์พัฒนาและสงเคราะห์ชาวเขา จังหวัดเชียงราย...
# กำลังประมวลผล index 179: เขามงคลพิพิธ...
# กำลังประมวลผล index 180: ศูนย์โอท็อปเชียงใหม่ ณ ข่วงสันกำแพง...
# กำลังประมวลผล index 181: พิพิธภัณฑ์หอยหิน 150 ล้านปี...
# กำลังประมวลผล index 182: อาร์ตอินพาราไดซ์ เชียงใหม่...
# กำลังประมวลผล index 183: พิพิธภัณฑ์ท้องถิ่นขุนละหาร...
# กำลังประมวลผล index 184: มหาเจดีย์ไตรภพไตรมงคล...
# กำลังประมวลผล index 185: พลับพลาที่ประทับริมเขื่อนท่าพระยาสาย...
# กำลังประมวลผล index 186: พิพิธภัณฑ์เมืองนราธิวาส...
# กำลังประมวลผล index 187: เมืองโบราณบ้านทุ่งตึก...
# กำลังประมวลผล index 188: วัดคงคาเลียบ...
# กำลังประมวลผล index 189: วัดแสงแก้วโพธิญาญ...
# กำลังประมวลผล index 190: วัดเขาเก้าแสน...
# กำลังประมวลผล index 191: กลุ่มสตรีพัฒนากล้วยน้ำว้าไทย...
# กำลังประมวลผล index 192: วัดแม่ซอดน่าด่าน...
# กำลังประมวลผล index 193: วัดชัยมงคล...
# กำลังประมวลผล index 194: วัดพระธาตุดอนแก้ว...
# กำลังประมวลผล index 195: พระธาตุตาลแหง...
# กำลังประมวลผล index 196: พระธาตุปูตั๊บ...
# กำลังประมวลผล index 197: น้ำตกซับสมบูรณ์...
# กำลังประมวลผล index 198: วัดพระธาตุจอมสวรรค์...
# กำลังประมวลผล index 199: ศูนย์เรียนรู้สุขภาพพึ่งตนตามแนวเศรษฐกิจพอเพียง สวนป่านาบุญ...
# กำลังประมวลผล index 200: ดอยแม่สลอง...
# กำลังประมวลผล index 201: หมู่บ้านกะเหรี่ยงรวมมิตร...
# กำลังประมวลผล index 202: พิพิธภัณฑสถานแห่งชาติหริภุญไชย...
# กำลังประมวลผล index 203: วูดแลนด์เมืองไม้...
# กำลังประมวลผล index 204: ศูนย์วิทยาศาสตร์เพื่อการศึกษาพิษณุโลก...
# กำลังประมวลผล index 205: วัดป่าสัก...
# กำลังประมวลผล index 206: ศาลหลักเมืองประจวบคีรีขันธ์...
# กำลังประมวลผล index 207: วัดถ้ำตับเต่า ...
# กำลังประมวลผล index 208: วัดศรีนวรัฐ...
# กำลังประมวลผล index 209: พิพิธภัณฑ์ตราไปรษณียากร เชียงใหม่...
# กำลังประมวลผล index 210: ภูแสนดาว...
# กำลังประมวลผล index 211: ม่อนล่อง...
# กำลังประมวลผล index 212: อุทยานแห่งชาติถ้ำปลา น้ำตกผาเสื่อ...
# กำลังประมวลผล index 213: ฟลอร่า พาร์ค...
# กำลังประมวลผล index 214: เลดี้ ฟาร์ม...
# กำลังประมวลผล index 215: ผาอกม้า...
# กำลังประมวลผล index 216: พระพุทธรูปในโพรงต้นไทร...
# กำลังประมวลผล index 217: ชุมชนท่องเที่ยวเชิงวัฒนธรรมชนเผ่าไทยข่า บ้านโสกแมว ...
# กำลังประมวลผล index 218: โครงการทิงค์พาร์ค...
# กำลังประมวลผล index 219: กลุ่มแม่บ้านเกษตรกร บ้านเขาตำหนอน...
# กำลังประมวลผล index 220: กลุ่มท่องเที่ยวชุมชนบ้านทุ่งนางดำ...
# กำลังประมวลผล index 221: วัดเจดีย์(ไอ้ไข่)...
# กำลังประมวลผล index 222: น้ำตกสุนันทา...
# กำลังประมวลผล index 223: วัดเขาลาน้ำ...
# กำลังประมวลผล index 224: หาดแห่ (บ้านน้ำก่ำ)...
# กำลังประมวลผล index 225: สถานแสดงพันธุ์สัตว์น้ำภาคเหนือ...
# กำลังประมวลผล index 226: สถานีพัฒนาเกษตรที่สูง ตามพระราชดำริ ดอยม่อนล้าน...
# กำลังประมวลผล index 227: สมอลล์ ฟาร์ม เชียงใหม่...
# กำลังประมวลผล index 228: บ้านภูไท โนนหอม...
# กำลังประมวลผล index 229: อ่าวยายเกิด...
# กำลังประมวลผล index 230: พิพิธภัณฑ์อัญมณีและเครื่องประดับ...
# กำลังประมวลผล index 231: ตลาดโรงเกลือ...
# กำลังประมวลผล index 232: วัดใหญ่ท่าเสา...
# กำลังประมวลผล index 233: พิพิธภัณฑ์เหมืองทองคำบ้านบ่อทอง...
# กำลังประมวลผล index 234: เกาะเสม็ด...
# กำลังประมวลผล index 235: เกาะทะลุ...
# กำลังประมวลผล index 236: สำนักสงฆ์น้ำตกธรรมรส...
# กำลังประมวลผล index 237: น้ำตกแควมะค่า...
# กำลังประมวลผล index 238: วัดพระปรางค์เหลือง...
# กำลังประมวลผล index 239: แหล่งโบราณสถานถ้ำศิลป์...
# กำลังประมวลผล index 240: วัดเจดีย์ยอดทอง...
# กำลังประมวลผล index 241: วัดศรีสวรรค์สังฆาราม (วัดถือน้ำ)...
# กำลังประมวลผล index 242: ศาลตายาย...
# กำลังประมวลผล index 243: น้ำตกแก่งลำดวน...
# กำลังประมวลผล index 244: อนุสาวรีย์พระนางจามเทวี...
# กำลังประมวลผล index 245: วัดวรนาถบรรพต (เขากบ)...
# กำลังประมวลผล index 246: อุทยานแห่งชาติแม่วะ...
# กำลังประมวลผล index 247: หอวัฒนธรรมวิทยาลัยครูอุตรดิตถ์...
# กำลังประมวลผล index 248: เกาะนุ้ยนอก...
# กำลังประมวลผล index 249: แหลมประทับ...
# กำลังประมวลผล index 250: โบราณสถานตุมปัง...
# กำลังประมวลผล index 251: น้ำพุร้อนโป่งปู่เฟือง...
# กำลังประมวลผล index 252: บ้านแสนใจพัฒนา...
# กำลังประมวลผล index 253: วัดพายัพ...
# กำลังประมวลผล index 254: เมืองฟ้าแดดสงยาง...
# กำลังประมวลผล index 255: หอศิลป์ทวี รัชนีกร...
# กำลังประมวลผล index 256: อะ คัฟ ออฟ เลิฟ...
# กำลังประมวลผล index 257: บ้านชลสุวรรณ ...
# กำลังประมวลผล index 258: วัดช่องแสมสาร...
# กำลังประมวลผล index 259: ชุมชนท่องเที่ยวตันหยงลุโละ...
# กำลังประมวลผล index 260: โฟล์วเฮาส์ แบงค์คอก...
# กำลังประมวลผล index 261: ฟาร์มจระเข้โภคธารา ...
# กำลังประมวลผล index 262: ถ้ำศรีเกษร...
# กำลังประมวลผล index 263: ทาร์ซาน แอดเวนเจอร์ ภูเก็ต...
# กำลังประมวลผล index 264: ชุมชนท่องเที่ยวจะบังติกอ...
# กำลังประมวลผล index 265: มายากลทักซิโด้ พัทยา...
# กำลังประมวลผล index 266: วัดครบุรี...
# กำลังประมวลผล index 267: หาดทรายแก้ว...
# กำลังประมวลผล index 268: ท่องเที่ยวเชิงนิเวศน์ตำบลบ้านขาว ...
# กำลังประมวลผล index 269: ทุ่งทานตะวันสงขลา...
# กำลังประมวลผล index 270: น้ำตกแม่ยะ...
# กำลังประมวลผล index 271: วัดโคกดอกไม้...
# กำลังประมวลผล index 272: วัดดอนตูมกมลาวาส...
# กำลังประมวลผล index 273: ฟาร์มแกะ พัทยา...
# กำลังประมวลผล index 274: มูลนิธิจักรพันธุ์ โปษยกฤต ...
# กำลังประมวลผล index 275: อ่างเก็บน้ำบ้านจรัส...
# กำลังประมวลผล index 276: สวนถาพร...
# กำลังประมวลผล index 277: บ้านหนองไข่เหี้ยโฮมสเตย์...
# กำลังประมวลผล index 278: สวนลุงเชษฐ์...
# กำลังประมวลผล index 279: วัดพรหมมหาจุฬามุณี พรหมรังษี...
# กำลังประมวลผล index 280: วัดวังตูม...
# กำลังประมวลผล index 281: วัดศรีนาวา...
# กำลังประมวลผล index 282: พิพิธภัณฑ์โรงเรียนวัดไร่ขิงวิทยา...
# กำลังประมวลผล index 283: ซีนิคอล เวิลด์ เขาใหญ่...
# กำลังประมวลผล index 284: โครงการพัฒนาพื้นที่แก้มลิงหนองเจ็ดเส้น อันเนื่องมาจากพระราชดำริ...
# กำลังประมวลผล index 285: โครงการฟาร์มตัวอย่างบ้านยางกลาง จังหวัดอ่างทอง...
# กำลังประมวลผล index 286: วัดพระใหญ่...
# กำลังประมวลผล index 287: กุฏิฤาษีบ้านหนองบัวลาย...
# กำลังประมวลผล index 288: ถนนคนเดิน เซราะกราว วอล์คกิ้ง สตรีท...
# กำลังประมวลผล index 289: ทะเลบ้านหมอ...
# กำลังประมวลผล index 290: วัดหนองแฟบ...
# กำลังประมวลผล index 291: จุดชมวิวเขาเหล็ก หรือทะเลหมอกกรุงชิง...
# กำลังประมวลผล index 292: วัดท่าคุระ...
# กำลังประมวลผล index 293: วัดปักคล้า...
# กำลังประมวลผล index 294: วัดป่าภูผาสูง...
# กำลังประมวลผล index 295: วัดป่าหลักร้อย...
# กำลังประมวลผล index 296: สำนักปฏิบัติธรรมวัดคลองตาลอง...
# กำลังประมวลผล index 297: หลักศิลาจารึก ร.5...
# กำลังประมวลผล index 298: พระธาตุเจดีย์ทะเมนชัย...
# กำลังประมวลผล index 299: วัดถ้ำแก้วกาญจนาภิเษก...
# กำลังประมวลผล index 300: วัดท่าขนุน...
# กำลังประมวลผล index 301: วัดเกริ่นกฐิน...
# กำลังประมวลผล index 302: วัดเชิงท่า...
# กำลังประมวลผล index 303: วัดท่านจั่น...
# กำลังประมวลผล index 304: วัดบ่อแร่...
# กำลังประมวลผล index 305: วัดพระยาตาก...
# กำลังประมวลผล index 306: วัดสิงห์สถิต...
# กำลังประมวลผล index 307: วัดสุวรรณโคตรมาราม (วัดคลองมอญ)...
# กำลังประมวลผล index 308: วัดกงไกรลาศ...
# กำลังประมวลผล index 309: ปราสาทนางรำ...
# กำลังประมวลผล index 310: กลุ่มสตรีสหกรณ์บ้านตะกุย...
# กำลังประมวลผล index 311: วนอุทยานน้ำตกเขาเจ้าบ่อทอง...
# กำลังประมวลผล index 312: วัดเกาะลอย...
# กำลังประมวลผล index 313: แก่งโตน...
# กำลังประมวลผล index 314: น้ำตกธารสวรรค์...
# กำลังประมวลผล index 315: วนอุทยานหริรักษ์...
# กำลังประมวลผล index 316: โครงการส่งเสริมศิลปาชีพบ้านทรายทอง...
# กำลังประมวลผล index 317: อุทยานสัตว์ป่าอุบลราชธานี...
# กำลังประมวลผล index 318: กลุ่มหัตถกรรมเครื่องเงินบ้านโชค...
# กำลังประมวลผล index 319: วัดพระบาทน้ำพุ...
# กำลังประมวลผล index 320: วัลลภาฟาร์ม...
# กำลังประมวลผล index 321: ศูนย์การทหารปืนใหญ่จังหวัดลพบุรี...
# กำลังประมวลผล index 322: วัดบุดดา...
# กำลังประมวลผล index 323: วัดสิงห์สุทธาวาส...
# กำลังประมวลผล index 324: พระธาตุ กว. วัดดอนนางหงส์...
# กำลังประมวลผล index 325: วัดพงษ์สุนันท์...
# กำลังประมวลผล index 326: วัดดอกไม้...
# กำลังประมวลผล index 327: หมู่บ้านประมงอ่าวสลัด...
# กำลังประมวลผล index 328: วิหารเทพวิทยาคม ...
# กำลังประมวลผล index 329: สวนพุทธมณฑลนครราชสีมา...
# กำลังประมวลผล index 330: ตลาดเก่าหันคา...
# กำลังประมวลผล index 331: บึงกระจับใหญ่...
# กำลังประมวลผล index 332: วัดประสิทธิเวช...
# กำลังประมวลผล index 333: น้ำตกมณฑาธาร...
# กำลังประมวลผล index 334: บ่อน้ำพุร้อนดอยสะเก็ด...
# กำลังประมวลผล index 335: บ้านใหม่สามัคคี...
# กำลังประมวลผล index 336: อุดมการ์เด้น...
# กำลังประมวลผล index 337: หาดท่าน้ำ ...
# กำลังประมวลผล index 338: อ่าวกะรัง...
# กำลังประมวลผล index 339: อ่าวขาว...
# กำลังประมวลผล index 340: อ่าวนิด...
# กำลังประมวลผล index 341: น้ำตกผาดอกเสี้ยว...
# กำลังประมวลผล index 342: เบิร์ดพาราไดซ์ เอ็กซ์ตรีม รีสอร์ท...
# กำลังประมวลผล index 343: อ่างเก็บน้ำบ้านอำปึล...
# กำลังประมวลผล index 344: สยามมิลซิม...
# กำลังประมวลผล index 345: อุทยานหินเขางู...
# กำลังประมวลผล index 346: พิพิธภัณฑ์ลิง...
# กำลังประมวลผล index 347: วัดเขาคอก...
# กำลังประมวลผล index 348: วัดเขานางบวช...
# กำลังประมวลผล index 349: สวนวิริยภูมิ...
# กำลังประมวลผล index 350: น้ำตกสะปัน...
# กำลังประมวลผล index 351: เกาะช้าง...
# กำลังประมวลผล index 352: บ้านไร่ ไออรุณ...
# กำลังประมวลผล index 353: ล้ง 1919...
# กำลังประมวลผล index 354: อุทยานเฉลิมกาญจนาภิเษก...
# กำลังประมวลผล index 355: อุทยานแห่งชาติหมู่เกาะสุรินทร์...
# กำลังประมวลผล index 356: อุทยานแห่งชาติดอยสุเทพ ปุย ...
# กำลังประมวลผล index 357: พิพิธภัณฑ์เฉลิมพระเกียรติเพื่อพัฒนาพื้นที่ลุ่มน้ำปากพนัง...
# กำลังประมวลผล index 358: กาดนั่งยองคล้องย่าม...
# กำลังประมวลผล index 359: บ้านคำปุน...
# กำลังประมวลผล index 360: ถนนสายดอกคูน...
# กำลังประมวลผล index 361: วิสาหกิจชุมชน กลุ่มท่องเที่ยวชุมชนบ้านโคกไคร...
# กำลังประมวลผล index 362: อุทยานแห่งชาติห้วยน้ำดัง ...
# กำลังประมวลผล index 363: วัดปงสนุกเหนือ...
# กำลังประมวลผล index 364: พระธาตุขามแก่น...
# กำลังประมวลผล index 365: เกาะพระทอง...
# กำลังประมวลผล index 366: ถ้ำเชียงดาว ...
# กำลังประมวลผล index 367: บ้านเสานัก...
# กำลังประมวลผล index 368: หมู่บ้านท่องเที่ยวเชิงอนุรักษ์ แม่กำปอง...
# กำลังประมวลผล index 369: บึงหนองทะเล...
# กำลังประมวลผล index 370: อุทยานแห่งชาติทุ่งแสลงหลวง...
# กำลังประมวลผล index 371: ถ้ำแม่ละนา...
# กำลังประมวลผล index 372: ผาเสด็จ...
# กำลังประมวลผล index 373: วนอุทยานบ่อน้ำร้อนกันตัง...
# กำลังประมวลผล index 374: เกาะช้าง...
# กำลังประมวลผล index 375: สวนพฤกษศาสตร์ภาคใต้ (ทุ่งค่าย)...
# กำลังประมวลผล index 376: สวนพฤกษศาสตร์ภาคใต้ (เขาช่อง)...
# กำลังประมวลผล index 377: เกาะสุกร...
# กำลังประมวลผล index 378: เกาะเหลาเหลียง...
# กำลังประมวลผล index 379: หอจดหมายเหตุแห่งชาติเฉลิมพระเกียรติพระบาทสมเด็จพระเจ้าอยู่หัวภูมิพลอดุลยเดช...
# กำลังประมวลผล index 380: ดงตาลสามโคก...
# กำลังประมวลผล index 381: เกาะลิบง...
# กำลังประมวลผล index 382: วัดป่าแสงอรุณ...
# กำลังประมวลผล index 383: พระมงคลมิ่งเมือง...
# กำลังประมวลผล index 384: วังผาเมฆ...
# กำลังประมวลผล index 385: วัดทุ่งเศรษฐี...
# กำลังประมวลผล index 386: เกาะพยาม...
# กำลังประมวลผล index 387: เขตรักษาพันธุ์สัตว์ป่าอุ้มผาง...
# กำลังประมวลผล index 388: วัดหนองแวง พระอารามหลวง...
# กำลังประมวลผล index 389: เกาะยาวใหญ่...
# กำลังประมวลผล index 390: โฮงซึงหลวง...
# กำลังประมวลผล index 391: ค่ายเจ้าเมืองระนอง...
# กำลังประมวลผล index 392: มีกินฟาร์ม...
# กำลังประมวลผล index 393: อุทยานประวัติศาสตร์พันท้ายนรสิงห์...
# กำลังประมวลผล index 394: ถนนคนเดินสันกำแพง...
# กำลังประมวลผล index 395: โฮงเจ้าฟองคำ...
# กำลังประมวลผล index 396: กว๊านพะเยา...
# กำลังประมวลผล index 397: สามเหลี่ยมทองคำ...
# กำลังประมวลผล index 398: บันไดปลาโจน...
# กำลังประมวลผล index 399: โครงการอนุรักษ์พันธุ์ไม้ป่าภาคตะวันออกเฉียงเหนือตอนบน...
# กำลังประมวลผล index 400: พระพุทธนวมินทรมงคลลีลาทวินคราภิรักษ์...
# กำลังประมวลผล index 401: วัดราชบัลลังก์...
# กำลังประมวลผล index 402: อุทยานแห่งชาติภูผายล...
# กำลังประมวลผล index 403: ยอดเขาพระบาท...
# กำลังประมวลผล index 404: ตลาดโก้งโค้ง บ้านแสงโสม...
# กำลังประมวลผล index 405: โรงไฟฟ้าพลังน้ำภาคตะวันออกเฉียงเหนือ เขื่อนอุบลรัตน์...
# กำลังประมวลผล index 406: น้ำตกเอราวัณ...
# กำลังประมวลผล index 407: สวนนงนุช...
# กำลังประมวลผล index 408: ซาฟารีเวิลด์...
# กำลังประมวลผล index 409: วัดถ้ำกระบอก...
# กำลังประมวลผล index 410: ตลาดในสวน...
# กำลังประมวลผล index 411: สนามมวยลุมพินี...
# กำลังประมวลผล index 412: ถ้ำเขาวัดชะอำคีรี...
# กำลังประมวลผล index 413: ชุมชนบ้านบาตร...
# กำลังประมวลผล index 414: ไร่รื่นรมย์...
# กำลังประมวลผล index 415: เมืองเก่าทับเที่ยง...
# กำลังประมวลผล index 416: ศูนย์ศึกษาธรรมชาติและท่องเที่ยวเชิงนิเวศเจ็ดคด โป่งก้อนเส้า...
# กำลังประมวลผล index 417: คาร์นิวัลเมจิก...
# กำลังประมวลผล index 418: วัดพระญาติการาม...
# กำลังประมวลผล index 419: ชุมชนบ้านไหนหนัง...
# กำลังประมวลผล index 420: มัสยิดกลางจังหวัดสตูล หรือมัสยิดมำบัง  ...
# กำลังประมวลผล index 421: กาดเกรียงไกรมาหามิตร...
# กำลังประมวลผล index 422: เฮือนสีมันตรา...
# กำลังประมวลผล index 423: ถ้ำเขาจูบกัน อุทยานแห่งชาติเขาสามร้อยยอด...
# กำลังประมวลผล index 424: แก่งหินปิด...
# กำลังประมวลผล index 425: บ้านไร่ตะวันหวาน กระบี่...
# กำลังประมวลผล index 426: เกาะเหลาลาดิง...
# กำลังประมวลผล index 427: อุทยานแห่งชาติอ่าวสยาม...
# กำลังประมวลผล index 428: ศูนย์เรียนรู้บ้านสำโหรง กุยบุรี...
# กำลังประมวลผล index 429: Sky Walk เหนือสุดในสยาม วัดพระธาตุดอยเวา...
# กำลังประมวลผล index 430: วัดเทพประทานพร...
# กำลังประมวลผล index 431: วัดคำเลา (วัดสีน้ำเงิน)...
# กำลังประมวลผล index 432: ถ้ำศิลป์ วัดร่องขุ่น...
# กำลังประมวลผล index 433: ศาลเจ้าปึงเฒ่ากง...
# กำลังประมวลผล index 434: ป่าครอบครัวบ้านหนองไม้แก่น...
# กำลังประมวลผล index 435: วัดเขาสวรรค์ตาก...
# กำลังประมวลผล index 436: โคโค่ คาวบอย สวนมะพร้าวน้ำหอมแปดริ้ว...
# กำลังประมวลผล index 437: หาดสุขสำราญ...
# กำลังประมวลผล index 438: ไร่ป๊ะป๋า...
# กำลังประมวลผล index 439: ถนนคนเดินท่าแพ...
# กำลังประมวลผล index 440: ชุมชนท่องเที่ยวบ้านเกาะมอญ   เกาะไผ่ ...
# กำลังประมวลผล index 441: โมริ เนเชอรัล ฟาร์ม...
# กำลังประมวลผล index 442: พิพิธภัณฑ์หนังใหญ่วัดพลับพลาชัย ...
# กำลังประมวลผล index 443: ชุมชนถ้ำรงค์...
# กำลังประมวลผล index 444: บ้านธารชีวี...
# กำลังประมวลผล index 445: ถ้ำโบ้ คีรีวงศ์...
# กำลังประมวลผล index 446: หินพัด (ชุมชนท่องเที่ยวบ้านยวนสาว)...
# กำลังประมวลผล index 447: สถานีวนวัฒนวิจัยบ่อแก้ว (สวนสนบ่อแก้ว)...
# กำลังประมวลผล index 448: ไร่สตอเบอรี่บ้านนอแล...
# กำลังประมวลผล index 449: ชุมชนท่องเที่ยวบ้านเดื่อ...
# กำลังประมวลผล index 450: วัดอโยธยา...
# กำลังประมวลผล index 451: ฮัก วิลเลจ ...
# กำลังประมวลผล index 452: ท่องเที่ยววิถีชุมชนปะโค...
# กำลังประมวลผล index 453: พิพิธภัณฑ์พระธาตุพระอริยสงฆ์ไทย...
# กำลังประมวลผล index 454: วัดบรมวงศ์อิศรวรารามวรวิหาร...
# กำลังประมวลผล index 455: วัดบ้านนา...
# กำลังประมวลผล index 456: วัดชุมนุมใน...
# กำลังประมวลผล index 457: วัดเขาเจดีย์วิสัยไตรรัตนาราม (วัดร้างชุมพร)...
# กำลังประมวลผล index 458: วิวพอยท์เกาะพีพีดอน...
# กำลังประมวลผล index 459: ตลาดนัดจริงใจ...
# กำลังประมวลผล index 460: น้ำตกเหวน้อย...
# กำลังประมวลผล index 461: น้ำตกโตนรากไทร...
# กำลังประมวลผล index 462: สกายวอล์กผาเงา สามแผ่นดิน...
# กำลังประมวลผล index 463: โรงเจเข่งซิ่วตั๊ว...
# กำลังประมวลผล index 464: ตลาดเก่าท่าเรือ...
# กำลังประมวลผล index 465: ศาลเจ้าโจวซือกง ...
# กำลังประมวลผล index 466: วัดถ้ำระฆัง...
# กำลังประมวลผล index 467: พระมหาเจดีย์มงคลบัว...
# กำลังประมวลผล index 468: เจดีย์หินวัดป่ากุง...
# กำลังประมวลผล index 469: ชมรมกีฬาขี่ม้า ชมวิวระยอง...
# กำลังประมวลผล index 470: เดอะฮอร์สแมน คาเฟ่ แอนด์ ฟาร์ม...
# กำลังประมวลผล index 471: อุโสถวัดท่าเรียบ...
# กำลังประมวลผล index 472: วัดพระพุทธบาทศรีสุราษฎร์...
# กำลังประมวลผล index 473: มิวเซียมสิงห์บุรี...
# กำลังประมวลผล index 474: วัดประสาท...
# กำลังประมวลผล index 475: วัดป่าพุทธาราม (ถ้ำสติ)...
# กำลังประมวลผล index 476: อาร์ต อิน พาราไดซ์ เชียงใหม่...
# กำลังประมวลผล index 477: จังเกิ้ล เดอ คาเฟ่ สาขาบัฟฟาโล่ ไอแลนด์...
# กำลังประมวลผล index 478: พิพิธภัณฑ์ตุ๊กตาเชียงใหม่...
# กำลังประมวลผล index 479: ป่าพรุแม่รำพึง...
# กำลังประมวลผล index 480: วัดฟ้าเวียงอินทร์  ...
# กำลังประมวลผล index 481: จุดชมวิว 1715...
# กำลังประมวลผล index 482: หอประวัติศาสตร์เชียงใหม่ ...
# กำลังประมวลผล index 483: พิพิธภัณฑ์รถจักรยานยนต์โล้วเฮงหมง...
# กำลังประมวลผล index 484: โบสถ์กาลหว่าร์ ...
# กำลังประมวลผล index 485: บ้านแกะ แม่ขิ...
# กำลังประมวลผล index 486: ถนนคนเดิน พานิชเจริญ...
# กำลังประมวลผล index 487: สวนชมพู่ลุงไพฑูรย์...
# กำลังประมวลผล index 488: ตลาดนัดมือสองของสะสมของทำมือ...
# กำลังประมวลผล index 489: เกาะผักเบี้ย...
# กำลังประมวลผล index 490: น้ำตกโป่งสะแยง ...
# กำลังประมวลผล index 491: กาดต๋องตึง บ้านริมน้ำ...
# กำลังประมวลผล index 492: เกาะนาคาน้อย...
# กำลังประมวลผล index 493: ตลาดเก่าอ่างศิลา...
# กำลังประมวลผล index 494: จุดถ่ายรูปเช็คอิน  Street Art ...
# กำลังประมวลผล index 495: ศูนย์เรียนรู้ป่าครอบครัว บ้านเขาน้อยห้วยตามา...
# กำลังประมวลผล index 496: ถ้ำธารลอดน้อย...
# กำลังประมวลผล index 497: อ่างเก็บน้ำห้วยกระพร้อย...
# กำลังประมวลผล index 498: ถนนคนเดินเมืองประจวบ...
# กำลังประมวลผล index 499: ดอยลังกาน้อย...
# กำลังประมวลผล index 500: ไร่คุณอารียา...
# กำลังประมวลผล index 501: Kob Aircraft @See Stars & Forest Resort ...
# กำลังประมวลผล index 502: สวนปาล์ม ฟาร์มนก...
# กำลังประมวลผล index 503: สถาบันอยุธยาศึกษา...
# กำลังประมวลผล index 504: ตลาดริมเลหัวหิน 19 ไร่...
# กำลังประมวลผล index 505: วัดกุยบุรี...
# กำลังประมวลผล index 506: ชุมชนก้นปึก...
# กำลังประมวลผล index 507: ภูตะวัน แคมป์ปิ้ง...
# กำลังประมวลผล index 508: บ้านไร่ภูเก็บตะวันแคมป์ปิ้ง  ระยอง...
# กำลังประมวลผล index 509: เขาพระพุทธบาทน้อย...
# กำลังประมวลผล index 510: หอดูดาว (เขาจอมแห)...
# กำลังประมวลผล index 511: พระจุฬามหาเจดีย์...
# กำลังประมวลผล index 512: วัดพระเกิด...
# กำลังประมวลผล index 513: ถนนโค้งพับผ้า...
# กำลังประมวลผล index 514: อ่างเก็บน้ำซับปลากั้ง...
# กำลังประมวลผล index 515: แหลมจมูกควาย...
# กำลังประมวลผล index 516: ดินแดงดอย...
# กำลังประมวลผล index 517: วัดมหาธาตุแหลมสัก...
# กำลังประมวลผล index 518: วัดชลประทานรังสรรค์...
# กำลังประมวลผล index 519: อุทยานธรรมชาติวิทยา ตามพระราชดำริสมเด็จพระเทพรัตนราชสุดาฯ สยามบรมราชกุมารี ...
# กำลังประมวลผล index 520: วัดเขาถ้ำ...
# กำลังประมวลผล index 521: วัดโบสถ์มณีศรีบุญเรือง...
# กำลังประมวลผล index 522: ศูนย์แสดงพันธุ์สัตว์น้ำจังหวัดศรีสะเกษ...
# กำลังประมวลผล index 523: ฟาร์มจระเข้วัดสิงห์...
# กำลังประมวลผล index 524: พระโพธิสัตว์กวนอิม (วัดทุ่งสมอ)...
# กำลังประมวลผล index 525: เกาะไม้ซี้...
# กำลังประมวลผล index 526: อ่างเก็บน้ำห้วยหนองโรง...
# กำลังประมวลผล index 527: วัดพระพุทธบาทดอยโล้น...
# กำลังประมวลผล index 528: วัดไชยาติการาม...
# กำลังประมวลผล index 529: อุทยานแห่งชาติภูผาเหล็ก...
# กำลังประมวลผล index 530: อนุสาวรีย์พระยาภักดีชุมพล...
# กำลังประมวลผล index 531: อ่าวท่าเลน...
# กำลังประมวลผล index 532: ตลาดหนองมน...
# กำลังประมวลผล index 533: วัดแจ้ง...
# กำลังประมวลผล index 534: เขื่อนมูลบน...
# กำลังประมวลผล index 535: ศาลหลักเมืองอุดรธานี...
# กำลังประมวลผล index 536: วัดพระแก้ว...
# กำลังประมวลผล index 537: วัดสองพี่น้อง...
# กำลังประมวลผล index 538: สวนลุงโชค...
# กำลังประมวลผล index 539: ศาลหลักเมืองแพร่  ...
# กำลังประมวลผล index 540: อุทยานลิลิตพระลอ ...
# กำลังประมวลผล index 541: ปราสาทสระกำแพงใหญ่...
# กำลังประมวลผล index 542: วัดโขดทิมธาราม...
# กำลังประมวลผล index 543: น้ำตกกะโรม...
# กำลังประมวลผล index 544: เขื่อนคีรีธาร...
# กำลังประมวลผล index 545: ชุมชนท่าหลวงบน โฮมสเตย์...
# กำลังประมวลผล index 546: ตลาดการค้าชายแดนไทย กัมพูชา ช่องบ้านผักกาด...
# กำลังประมวลผล index 547: วัดพระบาทมิ่งเมืองวรวิหาร...
# กำลังประมวลผล index 548: ศาลเจ้าพ่อแสนชัย ...
# กำลังประมวลผล index 549: วัดถ้ำคูหา ...
# กำลังประมวลผล index 550: ศาลาที่ประทับ ร.๕ หน้าวัดเขื่อนแดง...
# กำลังประมวลผล index 551: วัดพระธาตุดุม...
# กำลังประมวลผล index 552: วัดมาบจันทร์...
# กำลังประมวลผล index 553: วัดโพธิ์...
# กำลังประมวลผล index 554: ผาชัน...
# กำลังประมวลผล index 555: กลุ่มท่องเที่ยวชุมชนท่าฉาง...
# กำลังประมวลผล index 556: อนุสรณ์ผู้เสียสละ พ.ต.ท. 2324...
# กำลังประมวลผล index 557: วัดหมูเปิ้ง...
# กำลังประมวลผล index 558: ดอยขะม้อ บ่อน้ำทิพย์...
# กำลังประมวลผล index 559: วัดพระธาตุศรีมงคล...
# กำลังประมวลผล index 560: วัดเกาะหงษ์...
# กำลังประมวลผล index 561: น้ำตกปอย ...
# กำลังประมวลผล index 562: น้ำตกเหวสุวัต...
# กำลังประมวลผล index 563: เมืองเก่ากำแพงแสน...
# กำลังประมวลผล index 564: หอเกียรติยศ ฯพณฯ บรรหาร  ศิลปอาชา นายกรัฐมนตรีคนที่ 21...
# กำลังประมวลผล index 565: พิพิธภัณฑ์ลูกหลานพันธุ์มังกร ...
# กำลังประมวลผล index 566: ศาลเจ้าแสงธรรม...
# กำลังประมวลผล index 567: ศูนย์สืบทอดศิลปผ้าจก ราชบุรี...
# กำลังประมวลผล index 568: เกาะกูด...
# กำลังประมวลผล index 569: ชุมชนบ้านทาป่าเปา...
# กำลังประมวลผล index 570: วัดป่าฝาง...
# กำลังประมวลผล index 571: พระธาตุหล้าหนอง...
# กำลังประมวลผล index 572: พิพิธภัณฑ์หนังใหญ่วัดขนอน...
# กำลังประมวลผล index 573: หมู่บ้านไทยโซ่ง...
# กำลังประมวลผล index 574: วัดพระปรางค์...
# กำลังประมวลผล index 575: อุโมงค์รถไฟพระพุทธฉาย...
# กำลังประมวลผล index 576: วัดพระธาตุเสด็จ...
# กำลังประมวลผล index 577: วัดสันทรีย์...
# กำลังประมวลผล index 578: ถ้ำธรรมทัศน์...
# กำลังประมวลผล index 579: ศูนย์วิจัยและพัฒนาประมงชายฝั่งระยอง...
# กำลังประมวลผล index 580: ปราสาททอง...
# กำลังประมวลผล index 581: น้ำตกฉัตรวาริน...
# กำลังประมวลผล index 582: วัดธรรมาธิปไตย...
# กำลังประมวลผล index 583: สวนลุงสงค์ ศูนย์เรียนรู้การสกัดเย็นน้ำมันมะพร้าว...
# กำลังประมวลผล index 584: ล่องแพแม่วาง...
# กำลังประมวลผล index 585: กองบัญชาการกองทัพ 3 คณะชาติ ก๊กมินตั๋ง กองทัพ 93 (ถ้ำง๊อบ) ...
# กำลังประมวลผล index 586: บ้านไร่ไผ่งาม...
# กำลังประมวลผล index 587: ชุมชนตะเคียนเตี้ย...
# กำลังประมวลผล index 588: วนอุทยานภูพระ...
# กำลังประมวลผล index 589: วัดพระฝางสวางคบุรีมุนีนาถ  ...
# กำลังประมวลผล index 590: วัดศรีอุบลรัตนาราม (วัดศรีทอง) พระอารามหลวง...
# กำลังประมวลผล index 591: สถานแสดงพันธุ์สัตว์น้ำ บึงฉวากเฉลิมพระเกียรติ ...
# กำลังประมวลผล index 592: พิพิธภัณฑ์ธนาคารไทยลำปาง...
# กำลังประมวลผล index 593: อุโมงค์เบตงมงคลฤทธิ์...
# กำลังประมวลผล index 594: วัดพระธาตุเชิงชุมวรวิหาร...
# กำลังประมวลผล index 595: วัดสำปะซิว...
# กำลังประมวลผล index 596: สวนส้มธนาธร...
# กำลังประมวลผล index 597: อุทยานแห่งชาติแก่งตะนะ...
# กำลังประมวลผล index 598: พระพุทธบาทถ้ำป่าไผ่...
# กำลังประมวลผล index 599: วัดพระบรมธาตุไชยาราชวรวิหาร...
# กำลังประมวลผล index 600: บ้านลุงหนังฉิ้น อรมุต...
# กำลังประมวลผล index 601: ถ้ำบ่อยา (วัดเทพนิมิตทรงธรรม)...
# กำลังประมวลผล index 602: ตลาดร่มหุบ...
# กำลังประมวลผล index 603: โครงการศึกษาวิจัยและพัฒนาสิ่งแวดล้อมแหลมผักเบี้ย อันเนื่องมาจากพระราชดำริ...
# กำลังประมวลผล index 604: พิพิธภัณฑ์พื้นบ้านวัดม่วง...
# กำลังประมวลผล index 605: อ่างเก็บน้ำห้วยสิงห์...
# กำลังประมวลผล index 606: อ่าวยายไอ๋...
# กำลังประมวลผล index 607: วัดถ้ำผาจม...
# กำลังประมวลผล index 608: พระธาตุจำปา...
# กำลังประมวลผล index 609: พระบรมธาตุเจดีย์กาญจนาภิเษก...
# กำลังประมวลผล index 610: หาดสร้อยสวรรค์...
# กำลังประมวลผล index 611: จุดชมวิวผาชะโด...
# กำลังประมวลผล index 612: อุทยานแห่งชาติแจ้ซ้อน...
# กำลังประมวลผล index 613: อนุสาวรีย์สุเทวฤาษี...
# กำลังประมวลผล index 614: เนินมหัศจรรย์...
# กำลังประมวลผล index 615: แหลมจองถนน...
# กำลังประมวลผล index 616: บ้านทองสมสมัย ...
# กำลังประมวลผล index 617: อนุสาวรีย์พ่อขุนงำเมือง...
# กำลังประมวลผล index 618: วัดมหาวันวรมหาวิหาร...
# กำลังประมวลผล index 619: วัดพระนั่งดิน...
# กำลังประมวลผล index 620: วัดราชบูรณะ...
# กำลังประมวลผล index 621: วัดสุวรรณดารารามราชวรวิหาร...
# กำลังประมวลผล index 622: กลุ่มแม่บ้านจักสานพลาสติกศรีพราน...
# กำลังประมวลผล index 623: วัดทุ่งเสลี่ยม...
# กำลังประมวลผล index 624: เจดีย์พระบรมสารีริกธาตุเขาค้อ...
# กำลังประมวลผล index 625: อ่าวตะโล๊ะอุดัง...
# กำลังประมวลผล index 626: วัดเดิมบาง...
# กำลังประมวลผล index 627: วัดถ้ำเสือ...
# กำลังประมวลผล index 628: เกาะค้างคาว...
# กำลังประมวลผล index 629: ชุมชนบ้านน้ำฮูหายใจ...
# กำลังประมวลผล index 630: วัดสระแก้ว...
# กำลังประมวลผล index 631: หาดหัวหิน...
# กำลังประมวลผล index 632: วัดโอกาส (ศรีบัวบาน)...
# กำลังประมวลผล index 633: ตลาดลาดชะโด...
# กำลังประมวลผล index 634: วัดม่วง อ่างทอง...
# กำลังประมวลผล index 635: สถานีวิจัยเพาะเลี้ยงสัตว์ป่าภูเขียว...
# กำลังประมวลผล index 636: แก่งสนสามพันปี...
# กำลังประมวลผล index 637: สวนภัทรธร...
# กำลังประมวลผล index 638: เมืองจำลอง...
# กำลังประมวลผล index 639: วัดจุฬามณี อ่างทอง...
# กำลังประมวลผล index 640: วัดบางนมโค...
# กำลังประมวลผล index 641: ออบหลวง...
# กำลังประมวลผล index 642: โบราณสถานบ้านดอนเจดีย์...
# กำลังประมวลผล index 643: ผาหมอน...
# กำลังประมวลผล index 644: น้ำตกทุ่งนาเมือง...
# กำลังประมวลผล index 645: แก่งตุงลุง (แก่งจุลการ)...
# กำลังประมวลผล index 646: วนอุทยานประวัติศาสตร์เวียงเชียงรุ้ง...
# กำลังประมวลผล index 647: วัดศิลามงคล...
# กำลังประมวลผล index 648: ปราสาทบ้านปราสาท...
# กำลังประมวลผล index 649: พระธาตุเขาเขียว...
# กำลังประมวลผล index 650: เกาะง่าม...
# กำลังประมวลผล index 651: แม่น้ำโขง...
# กำลังประมวลผล index 652: วัดศรีดอนชัย...
# กำลังประมวลผล index 653: จุดชมวิวกิ่วลม...
# กำลังประมวลผล index 654: วัดเขาหัวสิงห์...
# กำลังประมวลผล index 655: สถานีรถไฟกันตัง...
# กำลังประมวลผล index 656: อ่างเก็บน้ำห้วยลิ้นควาย...
# กำลังประมวลผล index 657: บ้านแม่ตะละเหนือ...
# กำลังประมวลผล index 658: วัดปราสาท...
# กำลังประมวลผล index 659: พิพิธภัณฑสถานแห่งชาติจันทรเกษม ...
# กำลังประมวลผล index 660: วังปลาวัดข่อย...
# กำลังประมวลผล index 661: ปล่องเหลี่ยม...
# กำลังประมวลผล index 662: วัดบุปผาราม...
# กำลังประมวลผล index 663: วัดพรานนก...
# กำลังประมวลผล index 664: พระตำหนักคำหยาด...
# กำลังประมวลผล index 665: วัดมหัตตมังคลาราม ...
# กำลังประมวลผล index 666: วัดตระพังเงิน...
# กำลังประมวลผล index 667: ตลาดมหาชัย ...
# กำลังประมวลผล index 668: วัดพระธาตุท่าอุเทน...
# กำลังประมวลผล index 669: กองแลน...
# กำลังประมวลผล index 670: น้ำตกปูแกง...
# กำลังประมวลผล index 671: ถ้ำมาลัย...
# กำลังประมวลผล index 672: สถานีพัฒนาและส่งเสริมการอนุรักษ์สัตว์ป่าอุบลราชธานี...
# กำลังประมวลผล index 673: วัดพระธาตุสองพี่น้อง...
# กำลังประมวลผล index 674: เหมืองสมศักดิ์...
# กำลังประมวลผล index 675: น้ำตกปุญญบาล...
# กำลังประมวลผล index 676: น้ำตกแม่กลาง...
# กำลังประมวลผล index 677: วัดพระศรีมหาโพธิ์  ...
# กำลังประมวลผล index 678: ถนนอุทยาน  ...
# กำลังประมวลผล index 679: จุดชมวิวบริเวณห้วยน้ำดัง...
# กำลังประมวลผล index 680: ศูนย์แสดงพันธุ์สัตว์ป่าเขาประทับช้าง ...
# กำลังประมวลผล index 681: ศูนย์วิจัยทรัพยากรป่าชายเลนที่ 2 (สมุทรสาคร)...
# กำลังประมวลผล index 682: วัดถ้ำพระธาตุ ...
# กำลังประมวลผล index 683: ผาเกิ้ง...
# กำลังประมวลผล index 684: น้ำตกโป่งพระบาท...
# กำลังประมวลผล index 685: อนุสาวรีย์ยุวชนทหารสงครามโลก ครั้งที่ 2...
# กำลังประมวลผล index 686: ถ้ำจักรพงษ์...
# กำลังประมวลผล index 687: วัดสมณโกฏฐาราม...
# กำลังประมวลผล index 688: สวนรุกขชาติเขาฉกรรจ์...
# กำลังประมวลผล index 689: หมู่บ้านชาวประมงท่าฉลอม...
# กำลังประมวลผล index 690: วนอุทยานถ้ำจัน...
# กำลังประมวลผล index 691: บ้านเจ้าพระยาวิชาเยนทร์...
# กำลังประมวลผล index 692: ศูนย์วัฒนธรรมเชียงใหม่...
# กำลังประมวลผล index 693: หมู่บ้านกะเหรี่ยงแม่ปิง...
# กำลังประมวลผล index 694: วัดขุนอินทประมูล...
# กำลังประมวลผล index 695: หมู่บ้านกะเหรี่ยงคอยาวบ้านห้วยปูแกง...
# กำลังประมวลผล index 696: ถนนยมจินดา...
# กำลังประมวลผล index 697: วัดพระธาตุผาเงา...
# กำลังประมวลผล index 698: อ่าวมังกร...
# กำลังประมวลผล index 699: กำแพงค่าย พระยาเสนานุชิต...
# กำลังประมวลผล index 700: สถานีพัฒนาและส่งเสริมการอนุรักษ์สัตว์ป่าเขาน้ำพุ...
# กำลังประมวลผล index 701: สวนทุเรียนคุณป้าไสว...
# กำลังประมวลผล index 702: วัดโพธิ์บางคล้า...
# กำลังประมวลผล index 703: ทะเลหมอกหยุนไหล...
# กำลังประมวลผล index 704: ชุมชนเก่าชายทะเล (หมู่ 4 บ้านตลาดบางเสร่)...
# กำลังประมวลผล index 705: เขื่อนวชิราลงกรณ์...
# กำลังประมวลผล index 706: พิพิธภัณฑ์เมืองระยอง...
# กำลังประมวลผล index 707: อ่าวไร่เลย์...
# กำลังประมวลผล index 708: วัดผาสุการาม...
# กำลังประมวลผล index 709: น้ำพุร้อนหินดาด...
# กำลังประมวลผล index 710: ถ้ำพระ (ุถ้ำหมาไน...
# กำลังประมวลผล index 711: ตลาดกิมหยง...
# กำลังประมวลผล index 712: วัดเจดีย์แหลมสอ...
# กำลังประมวลผล index 713: วัดกู่เต้า...
# กำลังประมวลผล index 714: ชายทะเลบ้านนาใต้...
# กำลังประมวลผล index 715: เขื่อนหน้าเมืองนครพนม...
# กำลังประมวลผล index 716: กลุ่มหัตถกรรมเกวียนน้อย...
# กำลังประมวลผล index 717: โบราณสถานวัดโมคลาน...
# กำลังประมวลผล index 718: ศาลเจ้าพ่อหลักเมือง...
# กำลังประมวลผล index 719: วัดศรีจอมเมือง...
# กำลังประมวลผล index 720: วัดมณีไพรสณฑ์...
# กำลังประมวลผล index 721: วัดพระธาตุจอมสัก...
# กำลังประมวลผล index 722: วัดป่าภูทับเบิก...
# กำลังประมวลผล index 723: ชุมชนบ้านห้วยฮี้ ...
# กำลังประมวลผล index 724: กาดทุ่งเกวียน...
# กำลังประมวลผล index 725: อุทยานแห่งชาติผาแดง...
# กำลังประมวลผล index 726: วัดสระลงเรือ...
# กำลังประมวลผล index 727: วัดราษฎร์อุปถัมภ์ ...
# กำลังประมวลผล index 728: น้ำตกเซปละ...
# กำลังประมวลผล index 729: วนอุทยานถ้ำตะโค๊ะบิ...
# กำลังประมวลผล index 730: แหล่งโบราณคดีบ้านปราสาท...
# กำลังประมวลผล index 731: ชุมชนเกาะยอ...
# กำลังประมวลผล index 732: ผามะเกลือ...
# กำลังประมวลผล index 733: วัดถ้ำเขาขุนกระทิง...
# กำลังประมวลผล index 734: วัดป่าประดู่...
# กำลังประมวลผล index 735: น้ำตกวชิรธาร...
# กำลังประมวลผล index 736: วัดใหญ่ทักขิณาราม...
# กำลังประมวลผล index 737: อุทยานแห่งชาติน้ำตกซีโป...
# กำลังประมวลผล index 738: วัดอินทาราม  ...
# กำลังประมวลผล index 739: พระตำหนักทักษิณราชนิเวศน์...
# กำลังประมวลผล index 740: วัดสามชุก...
# กำลังประมวลผล index 741: น้ำตกป่าหวาย...
# กำลังประมวลผล index 742: บ่อน้ำบุ้น...
# กำลังประมวลผล index 743: วัดอรัญญิก...
# กำลังประมวลผล index 744: ผาวิ่งชู้...
# กำลังประมวลผล index 745: ถ้ำผีแมน...
# กำลังประมวลผล index 746: น้ำตกตาดหมอก...
# กำลังประมวลผล index 747: ภูทับเบิก...
# กำลังประมวลผล index 748: อุทยานประวัติศาสตร์ศรีสัชนาลัย...
# กำลังประมวลผล index 749: หาดทรายแก้ว...
# กำลังประมวลผล index 750: จุดผ่านแดนไทย พม่า อำเภอแม่สาย...
# กำลังประมวลผล index 751: ปราสาทหินพนมวัน...
# กำลังประมวลผล index 752: ชายแดนไทย ลาว อำเภอเชียงแสน...
# กำลังประมวลผล index 753: วัดเขาบังเหยชุมพลสีมาราม...
# กำลังประมวลผล index 754: วัดพืชอุดม...
# กำลังประมวลผล index 755: ถ้ำธารลอดใหญ่...
# กำลังประมวลผล index 756: วัดเจดีย์หอย...
# กำลังประมวลผล index 757: น้ำตกคลองเจ้า...
# กำลังประมวลผล index 758: ตลาดสันติสุข...
# กำลังประมวลผล index 759: พิพิธภัณฑ์อูบคำ...
# กำลังประมวลผล index 760: สวนสมเด็จพระศรีนครินทร์ฉะเชิงเทรา...
# กำลังประมวลผล index 761: วัดยาง...
# กำลังประมวลผล index 762: หมู่บ้านทำกลองตำบลเอกราช...
# กำลังประมวลผล index 763: วัดท้ายย่าน...
# กำลังประมวลผล index 764: วัดป่าชัยรังสี...
# กำลังประมวลผล index 765: หาดป่าทราย...
# กำลังประมวลผล index 766: วัดเขียนบูรพาราม...
# กำลังประมวลผล index 767: หาดคลองหิน...
# กำลังประมวลผล index 768: อ่าวนุ่น...
# กำลังประมวลผล index 769: ตลาดฉัตรไชย...
# กำลังประมวลผล index 770: วัดเสาธงหิน...
# กำลังประมวลผล index 771: วัดปรางค์หลวง...
# กำลังประมวลผล index 772: อ่าวยาง...
# กำลังประมวลผล index 773: หาดไก่แบ้...
# กำลังประมวลผล index 774: หาดสะพลี...
# กำลังประมวลผล index 775: วัดพระนอน...
# กำลังประมวลผล index 776: วัดแก้วฟ้า...
# กำลังประมวลผล index 777: สถาบันวิจัยไม้กลายเป็นหินและทรัพยากรธรณีภาคตะวันออกเฉียงเหนือเฉลิมพระเกียรติมหาวิทยาลัยราชภัฏนครราชสีมา...
# กำลังประมวลผล index 778: วัดราชบูรณะ พระนครศรีอยุธยา...
# กำลังประมวลผล index 779: ซัพบอร์ด เวียงสา...
# กำลังประมวลผล index 780: วัดสะตือ พุทธไสยาสน์...
# กำลังประมวลผล index 781: น้ำตกสวนมะเดื่อ...
# กำลังประมวลผล index 782: วัดหน้าพระธาตุ...
# กำลังประมวลผล index 783: น้ำตกโตนช่องฟ้า...
# กำลังประมวลผล index 784: ภูโคลน คันทรีคลับ เฮลท์ มัท สปา ...
# กำลังประมวลผล index 785: น้ำตกลานสาง...
# กำลังประมวลผล index 786: เกาะยาวน้อย...
# กำลังประมวลผล index 787: สวนไม้ดอกเมืองหนาวเบตง...
# กำลังประมวลผล index 788: วัดวิหารทอง...
# กำลังประมวลผล index 789: ปราสาทภูมิโปน...
# กำลังประมวลผล index 790: ศูนย์ภูมิรักษ์ธรรมชาติ...
# กำลังประมวลผล index 791: น้ำตกไพรวัลย์...
# กำลังประมวลผล index 792: ศาลสมเด็จพระนเรศวรมหาราช...
# กำลังประมวลผล index 793: หาดภราดรภาพ...
# กำลังประมวลผล index 794: วัดพระธาตุแม่เย็น...
# กำลังประมวลผล index 795: ผาขาม...
# กำลังประมวลผล index 796: วัดถ้ำพระพุทธไสยาสน์ ...
# กำลังประมวลผล index 797: ศูนย์ส่งเสริมและพัฒนาอาชีพการเกษตรจังหวัดเชียงราย (เกษตรที่สูง) ...
# กำลังประมวลผล index 798: อุทยานสมเด็จย่า  (ฐานวรพัฒน์)...
# กำลังประมวลผล index 799: อนุสรณ์สถานผู้เสียสละ (เขาค้อ)...
# กำลังประมวลผล index 800: หาดกะตะน้อย...
# กำลังประมวลผล index 801: ถ้ำพิสดาร...
# กำลังประมวลผล index 802: อ่างเก็บน้ำทรายทอง...
# กำลังประมวลผล index 803: น้ำตกโยง...
# กำลังประมวลผล index 804: วนอุทยานชะอำ...
# กำลังประมวลผล index 805: น้ำตกตาดโตน...
# กำลังประมวลผล index 806: เลค แลนด์ วอเตอร์ เคเบิ้ล สกี...
# กำลังประมวลผล index 807: เมืองโบราณอู่ตะเภา...
# กำลังประมวลผล index 808: วัดพระธาตุภูปอ...
# กำลังประมวลผล index 809: เกาะลอย หรือ หนองน้ำมณีบรรพต...
# กำลังประมวลผล index 810: อ่าวทุ่งมะขาม...
# กำลังประมวลผล index 811: พระราชนิเวศน์มฤคทายวัน...
# กำลังประมวลผล index 812: วัดพระพุทธบาทภูแฝด...
# กำลังประมวลผล index 813: วัดหนองเงือก...
# กำลังประมวลผล index 814: ทุ่งทานตะวันลุงสายันห์...
# กำลังประมวลผล index 815: วัดนครสวรรค์ (วัดหัวเมือง)...
# กำลังประมวลผล index 816: พระบรมรูปรัชกาลที่ 8 วัดนางรอง นครนายก...
# กำลังประมวลผล index 817: อุทยานแห่งชาติป่าหินงาม...
# กำลังประมวลผล index 818: บึงโขงหลง...
# กำลังประมวลผล index 819: สวนส้มโอพวงฉัตร...
# กำลังประมวลผล index 820: ศาลหลักเมือง อ่างทอง...
# กำลังประมวลผล index 821: หมู่บ้านปากน้ำปราณ...
# กำลังประมวลผล index 822: วิสาหกิจชุมชนผู้ผลิตมะม่วง (ตลาดมะม่วง อ.บางคล้า)...
# กำลังประมวลผล index 823: อนุสาวรีย์พระเจ้าบรมวงศ์เธอกรมหลวงประจักษ์ศิลปาคม...
# กำลังประมวลผล index 824: กลุ่มจักรสานบ้านมหานาม...
# กำลังประมวลผล index 825: วัดราชปักษี (นก)...
# กำลังประมวลผล index 826: น้ำตกตะโหมด ...
# กำลังประมวลผล index 827: วัดป่าพฤกษ์...
# กำลังประมวลผล index 828: สวนสัตว์ลพบุรี...
# กำลังประมวลผล index 829: ชุมชนบ้านนาป่าแปก...
# กำลังประมวลผล index 830: สะพานมิตรภาพไทย พม่า...
# กำลังประมวลผล index 831: น้ำตกห้วยต้นผึ้ง...
# กำลังประมวลผล index 832: ถ้ำแม่อุษา...
# กำลังประมวลผล index 833: น้ำตกสะพานหิน...
# กำลังประมวลผล index 834: ถ้ำพุงช้าง...
# กำลังประมวลผล index 835: ศูนย์วัฒนธรรมไทลื้อ (วัดหย่วน)...
# กำลังประมวลผล index 836: ถ้ำแก้วสุรกานต์...
# กำลังประมวลผล index 837: ดอยปู่หมื่น...
# กำลังประมวลผล index 838: พระธาตุนางเพ็ญ...
# กำลังประมวลผล index 839: ฮาย ริเวอร์ คาเฟ่...
# กำลังประมวลผล index 840: เกาะเทโพ ...
# กำลังประมวลผล index 841: วัดมเหยงคณ์...
# กำลังประมวลผล index 842: วัดสิงห์...
# กำลังประมวลผล index 843: สถานีรถไฟบางกอกน้อย (สถานีรถไฟธนบุรี)...
# กำลังประมวลผล index 844: พระเจดีย์กลางน้ำ...
# กำลังประมวลผล index 845: สะพานแขวนภูเขารูปหัวใจเขาพังและสวนทุเรียน 100 ปี...
# กำลังประมวลผล index 846: กาดเมกฮิมคือ...
# กำลังประมวลผล index 847: หมู่บ้านประมงบางเบ้า...
# กำลังประมวลผล index 848: เจดีย์พระศรีสุริโยทัย...
# กำลังประมวลผล index 849: อ่างเก็บน้ำถ้ำเสาหินพญานาค...
# กำลังประมวลผล index 850: กะหลิม ริมเล...
# กำลังประมวลผล index 851: น้ำตกทุ่งนางครวญ...
# กำลังประมวลผล index 852: ตลาดนัดจตุจักร...
# กำลังประมวลผล index 853: พิพิธภัณฑสถานแห่งชาติอินทร์บุรี...
# กำลังประมวลผล index 854: อ่างเก็บน้ำห้วยตาดควัน...
# กำลังประมวลผล index 855: มิสซังโรมันคาทอลิก ท่าแร่ หนองแสง...
# กำลังประมวลผล index 856: วัดเกษรศีลคุณ(วัดป่าบ้านตาด) ...
# กำลังประมวลผล index 857: วัดมณีชลขัณฑ์...
# กำลังประมวลผล index 858: ตลาดอินโดจีน...
# กำลังประมวลผล index 859: หนองเล็งทราย...
# กำลังประมวลผล index 860: วัดพระธาตุสามดวง...
# กำลังประมวลผล index 861: วัดประตูสาร...
# กำลังประมวลผล index 862: ศาลหลักเมืองมุกดาหาร...
# กำลังประมวลผล index 863: วัดชมภูเวก...
# กำลังประมวลผล index 864: ศาลหลักเมืองจังหวัดนครพนม...
# กำลังประมวลผล index 865: อ่าวตะเภา...
# กำลังประมวลผล index 866: อ่างเก็บน้ำห้วยปรือ...
# กำลังประมวลผล index 867: เม้าท์เท้น ชาโดว์ กอล์ฟ คลับ...
# กำลังประมวลผล index 868: หมู่บ้านกะเหรี่ยง ปะละทะ...
# กำลังประมวลผล index 869: วัดป่าศรีถาวรนิมิต...
# กำลังประมวลผล index 870: วัดราชคฤห์วรวิหาร...
# กำลังประมวลผล index 871: วัดหนองจรเข้...
# กำลังประมวลผล index 872: ศาลพระปรง...
# กำลังประมวลผล index 873: น้ำตกตะวันรัศมี...
# กำลังประมวลผล index 874: สวนสนุกพัทยาปาร์ค...
# กำลังประมวลผล index 875: อุทยานแห่งชาติน้ำตกหงาว...
# กำลังประมวลผล index 876: ศูนย์วัฒนธรรมแห่งประเทศไทย...
# กำลังประมวลผล index 877: เกาะไผ่...
# กำลังประมวลผล index 878: วัดมหาชัย...
# กำลังประมวลผล index 879: วัดป่าสาลวัน...
# กำลังประมวลผล index 880: อ่าวช่องขาด...
# กำลังประมวลผล index 881: วัดถ้ำตลอด...
# กำลังประมวลผล index 882: จุดชมวิวเขารัง...
# กำลังประมวลผล index 883: วัดเวฬุวัน...
# กำลังประมวลผล index 884: โป่งน้ำร้อนห้วยหินฝน...
# กำลังประมวลผล index 885: สระศักดิ์สิทธิ์ทั้ง 4...
# กำลังประมวลผล index 886: วัดพระแท่นดงรังวรวิหาร...
# กำลังประมวลผล index 887: ลานผาผึ้ง...
# กำลังประมวลผล index 888: อนุสรณ์สถานแห่งความสงบภูพานน้อย...
# กำลังประมวลผล index 889: จุดชมวิวบริเวณสะพานเฉลิมพระเกียรติ...
# กำลังประมวลผล index 890: อ่าวสลัด...
# กำลังประมวลผล index 891: หมู่บ้านทำร่มบ่อสร้าง...
# กำลังประมวลผล index 892: ค่ายบางกุ้ง...
# กำลังประมวลผล index 893: เสาร้องไห้ (วัดสูง)...
# กำลังประมวลผล index 894: สวนสาธารณะเกาะลำพู...
# กำลังประมวลผล index 895: วัดป่าเจดีย์เหลี่ยม...
# กำลังประมวลผล index 896: กะเหรี่ยงคอยาวบ้านห้วยเสือเฒ่า...
# กำลังประมวลผล index 897: ศูนย์ผลิตภัณฑ์ผ้าไหมบ้านเป๊าะ...
# กำลังประมวลผล index 898: วัดพระพุทธบาทราชวรมหาวิหาร...
# กำลังประมวลผล index 899: ศูนย์ศึกษาการพัฒนาเขาหินซ้อน อันเนื่องมาจากพระราชดำริ...
# กำลังประมวลผล index 900: แหลมสมิหลา...
# กำลังประมวลผล index 901: ทุ่งทะเลหลวง...
# กำลังประมวลผล index 902: เกาะสาก...
# กำลังประมวลผล index 903: วัดถนน...
# กำลังประมวลผล index 904: วัดศรีเทพประดิษฐาราม ...
# กำลังประมวลผล index 905: วัดท่าสุทธาวาส...
# กำลังประมวลผล index 906: ดอยวาวี ...
# กำลังประมวลผล index 907: น้ำตกห้วยน้ำดัง...
# กำลังประมวลผล index 908: เกาะล้าน...
# กำลังประมวลผล index 909: ศูนย์วิจัยและพัฒนาประมงน้ำจืดพะเยา...
# กำลังประมวลผล index 910: อนุสาวรีย์ท้าวสุรนารี...
# กำลังประมวลผล index 911: ถ้ำยางวี...
# กำลังประมวลผล index 912: เส้นทางรถไฟสายมรณะ...
# กำลังประมวลผล index 913: น้ำตกธารสวรรค์...
# กำลังประมวลผล index 914: พระพุทธบาทบัวบก...
# กำลังประมวลผล index 915: น้ำตกห้วยหลวง...
# กำลังประมวลผล index 916: ขุนน้ำโป่ง...
# กำลังประมวลผล index 917: วัดเสนาสนารามราชวรวิหาร...
# กำลังประมวลผล index 918: ชุมชนบ้านท่าแร่...
# กำลังประมวลผล index 919: วัดป่ากลางโนนภู่...
# กำลังประมวลผล index 920: ปรางค์กู่สวนแตง...
# กำลังประมวลผล index 921: ปราสาทเมืองต่ำ...
# กำลังประมวลผล index 922: วัดบ้านเด่น...
# กำลังประมวลผล index 923: เขตรักษาพันธุ์สัตว์ป่าสลักพระ...
# กำลังประมวลผล index 924: จุดชมวิวภูหอ...
# กำลังประมวลผล index 925: เขตห้ามล่าสัตว์ป่าอ่างเก็บน้ำสนามบิน...
# กำลังประมวลผล index 926: วัดพระเจ้าทองทิพย์ ...
# กำลังประมวลผล index 927: เขาช่องพราน...
# กำลังประมวลผล index 928: วัดสระเกษ...
# กำลังประมวลผล index 929: ถ้ำทิพย์ปรีดา...
# กำลังประมวลผล index 930: อุโมงค์ประวัติศาสตร์เขาน้ำค้าง...
# กำลังประมวลผล index 931: อุทยานแห่งชาติน้ำหนาว...
# กำลังประมวลผล index 932: วัดโลกยสุธาราม...
# กำลังประมวลผล index 933: น้ำตกแซหัวแมว...
# กำลังประมวลผล index 934: วงเวียนศรีสุริโยทัย...
# กำลังประมวลผล index 935: เขาพิงกัน...
# กำลังประมวลผล index 936: พิพิธภัณฑสถานแห่งชาติ มัชฌิมาวาส...
# กำลังประมวลผล index 937: น้ำตกม่านธารา...
# กำลังประมวลผล index 938: สวนกล้วยไม้ศิริพร...
# กำลังประมวลผล index 939: วัดมัชฌิมาวาสและกลองมโหระทึกโบราณ...
# กำลังประมวลผล index 940: น้ำตกห้วยใหญ่...
# กำลังประมวลผล index 941: วัดนิเวศธรรมประวัติราชวรวิหาร...
# กำลังประมวลผล index 942: กำแพงเมืองสงขลา...
# กำลังประมวลผล index 943: โป่งน้ำร้อนท่าปาย...
# กำลังประมวลผล index 944: วัดศรีดอนชัย...
# กำลังประมวลผล index 945: หาดยะนุ้ย...
# กำลังประมวลผล index 946: หอศิลปวัฒนธรรม...
# กำลังประมวลผล index 947: บ้านปางสา...
# กำลังประมวลผล index 948: ชุมชนท่องเที่ยวเชิงวัฒนธรรมชนเผ่าไทกวนบ้านนาถ่อน...
# กำลังประมวลผล index 949: บ้านชาวเขาเผ่าลาหู่...
# กำลังประมวลผล index 950: ด่านเจดีย์สามองค์...
# กำลังประมวลผล index 951: ปราสาทสด๊กก๊อกธม...
# กำลังประมวลผล index 952: เกาะปันหยี...
# กำลังประมวลผล index 953: วัดสามแก้ว...
# กำลังประมวลผล index 954: กลุ่มทอผ้าฝ้ายมัดหมี่บ้านวาใหญ่...
# กำลังประมวลผล index 955: วัดบางกระเบา...
# กำลังประมวลผล index 956: ภาพเขียนสีก่อนประวัติศาสตร์ที่ผาแต้ม...
# กำลังประมวลผล index 957: แก่งบกไฟ...
# กำลังประมวลผล index 958: ตลาดไท...
# กำลังประมวลผล index 959: อ่างเก็บน้ำห้วยเฉลียงลับ...
# กำลังประมวลผล index 960: ถนนคนเดินสงขลาแต่แรก...
# กำลังประมวลผล index 961: น้ำตกไตรตรึงษ์...
# กำลังประมวลผล index 962: กำแพงเมืองเก่าและประตูเมือง...
# กำลังประมวลผล index 963: คูค่ายพม่า...
# กำลังประมวลผล index 964: โรงงานทำเครื่องเขิน...
# กำลังประมวลผล index 965: ศาลหลักเมือง...
# กำลังประมวลผล index 966: ปราสาทนครหลวง...
# กำลังประมวลผล index 967: ตลาดน้ำชุมชนวัดศรีวารีน้อย...
# กำลังประมวลผล index 968: พระราชวังเดิม (กองทัพเรือ)...
# กำลังประมวลผล index 969: กวานอาม่าน...
# กำลังประมวลผล index 970: ดอยหัวหมด...
# กำลังประมวลผล index 971: วัดปงยางคก...
# กำลังประมวลผล index 972: วัดสุทธาวาส วิปัสสนา...
# กำลังประมวลผล index 973: ตุ้งโร่ ฟู้ดมาร์เก็ต แปดริ้ว...
# กำลังประมวลผล index 974: บ่อน้ำร้อนผาบ่อง...
# กำลังประมวลผล index 975: พิพิธภัณฑ์วิถีชีวิตชาวนาไทยบ้านลานแหลม...
# กำลังประมวลผล index 976: อุทยานแห่งชาติสาละวิน...
# กำลังประมวลผล index 977: วัดหนองป่าพง...
# กำลังประมวลผล index 978: หาดมหาราช...
# กำลังประมวลผล index 979: น้ำตกสิรินธร...
# กำลังประมวลผล index 980: วัดนารายณิการาม...
# กำลังประมวลผล index 981: วัดเชิงเขา...
# กำลังประมวลผล index 982: วัดพระธาตุมหาชัย...
# กำลังประมวลผล index 983: วัดสุทธาวาส...
# กำลังประมวลผล index 984: น้ำตกผาตาด...
# กำลังประมวลผล index 985: วัดเอกา...
# กำลังประมวลผล index 986: มูลนิธิบ้านสงเคราะห์สัตว์พิการ...
# กำลังประมวลผล index 987: วัดศรีสุพรรณ...
# กำลังประมวลผล index 988: น้ำตกธารเงิน...
# กำลังประมวลผล index 989: เชียงรายไนท์บาซ่าร์ ...
# กำลังประมวลผล index 990: ศูนย์ศิลปวัฒนธรรมกาญจนาภิเษกอุบลราชธานี...
# กำลังประมวลผล index 991: น้ำตกบริพัตร...
# กำลังประมวลผล index 992: ภูผาแต้ม...
# กำลังประมวลผล index 993: คุ้มขุนแผน...
# กำลังประมวลผล index 994: ประตูพลล้าน...
# กำลังประมวลผล index 995: วัดสัตหีบ...
# กำลังประมวลผล index 996: วัดคงคาราม และจิตรกรรมฝาผนัง...
# กำลังประมวลผล index 997: พิพิธภัณฑ์ชาวบางกอก...
# กำลังประมวลผล index 998: เดอะ สีลมแกลเลอเรีย อาร์ตสเปซ  ...
# กำลังประมวลผล index 999: สวนลุมพินี...
# กำลังประมวลผล index 1000: วัดพระนอน...
# กำลังประมวลผล index 1001: วัดหัวเวียงรังษี...
# กำลังประมวลผล index 1002: สะพานหินธรรมชาติ...
# กำลังประมวลผล index 1003: วัดหน้าพระธาตุ...
# กำลังประมวลผล index 1004: สวนบอนไซ...
# กำลังประมวลผล index 1005: โบราณสถานเวียงลอ...
# กำลังประมวลผล index 1006: สวนสัตว์นครราชสีมา...
# กำลังประมวลผล index 1007: น้ำตกแสงจันทร์...
# ...
# กำลังประมวลผล index 7980: พุทธสถานภูปอ...
# กำลังประมวลผล index 7981: วัดพระธาตุจอมแจ้ง...
# กำลังประมวลผล index 7982: น้ำตกอินทสร...
# กำลังประมวลผล index 7983: ถนนนิมมานเหมินทร์...
# กำลังประมวลผล index 7984: วัดสระหงษ์...
# กำลังประมวลผล index 7985: อุทยานแห่งชาติภูลังกา...
# กำลังประมวลผล index 7986: วัดภูพานอุดมธรรม...
# กำลังประมวลผล index 7987: วัดราษฎร์บูรณะ (วัดช้างให้)...
# กำลังประมวลผล index 7988: เขื่อนแควน้อยบำรุงแดน  ...
# กำลังประมวลผล index 7989: พิพิธภัณฑสถานแห่งชาติชัยนาทมุนี...
# กำลังประมวลผล index 7990: สถานีเพาะเลี้ยงสัตว์ป่าเขาค้อ...
# กำลังประมวลผล index 7991: วัดประเดิม...
# กำลังประมวลผล index 7992: ศูนย์อนุรักษ์และศึกษาระบบนิเวศป่าชายเลน โรงเรียนบางตะบูนวิทยา...
# กำลังประมวลผล index 7993: สักการสถาน บุญราศีนิโคลาส บุญเกิด...
# กำลังประมวลผล index 7994: วัดถ้ำเขารูปช้าง...
# กำลังประมวลผล index 7995: ศาลเจ้าแม่ทับทิมท่าฬ่อ...
# กำลังประมวลผล index 7996: บ่อพันขันรัตนโสภณ...
# กำลังประมวลผล index 7997: กู่กาสิงห์...
# กำลังประมวลผล index 7998: เขื่อนกิ่วลม...
# กำลังประมวลผล index 7999: ศาลจังหวัดและศาลากลางจังหวัดสิงห์บุรีหลังเก่า...
# กำลังประมวลผล index 8000: ศาลเจ้าแม่หน้าผา...
# กำลังประมวลผล index 8001: วัดเจษฎาราม...
# กำลังประมวลผล index 8002: เขาคีรีวงกตภูมะโรง...
# กำลังประมวลผล index 8003: โฮมสเตย์เบิ่งวัฒนธรรมหมอลำบ้านปลาค้าว...
# กำลังประมวลผล index 8004: วนอุทยานแห่งชาติสระนางมโนห์รา...
# กำลังประมวลผล index 8005: หาดไม้งาม...
# กำลังประมวลผล index 8006: สนามกอล์ฟ ปัตตาเวีย เซ็นจูรี่ กอล์ฟ คลับ (ชลบุรี เซ็นจูรี่)...
# กำลังประมวลผล index 8007: ศูนย์บริการท่องเที่ยวเชิงเกษตร (ศกร.)...
# กำลังประมวลผล index 8008: ศาลเจ้าพ่อหลักเมือง...
# กำลังประมวลผล index 8009: วัดป่าเลไลยก์วรวิหาร...
# กำลังประมวลผล index 8010: ชุมชนท่องเที่ยวเชิงวัฒนธรรมชนเผ่าไทกวน ...
# กำลังประมวลผล index 8011: วัดพระรูป...
# กำลังประมวลผล index 8012: สถานีพัฒนาการเกษตรที่สูงตามพระราชดำริ ภูพยัคฆ์ ...
# กำลังประมวลผล index 8013: อุทยานแห่งชาติภูแลนคา...
# กำลังประมวลผล index 8014: ถ้ำฤาษีเขางู...
# กำลังประมวลผล index 8015: แอร์ออร์คิด ซูเปอร์มาร์เก็ตกล้วยไม้...
# กำลังประมวลผล index 8016: เมืองโบราณบ้านคูเมือง...
# กำลังประมวลผล index 8017: วัดเขาท่าพระ...
# กำลังประมวลผล index 8018: วัดตองปุ...
# กำลังประมวลผล index 8019: ศูนย์ศึกษาธรรมชาติและอนุรักษ์ป่าชายเลนเพื่อการท่องเที่ยวเชิงนิเวศ...
# กำลังประมวลผล index 8020: ศูนย์ธรรมชาติวิทยาดอยสุเทพเฉลิมพระเกียรติฯ...
# กำลังประมวลผล index 8021: สวนสาธารณะหนองถิ่น...
# กำลังประมวลผล index 8022: โครงการสบขุ่นโมเดล บ้านสบขุ่น...
# กำลังประมวลผล index 8023: โม่งทรายบีช...
# กำลังประมวลผล index 8024: ชุมชนท่องเที่ยวสุไหงตำมะลัง...
# กำลังประมวลผล index 8025: วิสาหกิจชุมชนท่องเที่ยววิถีชุมชนเชิงเกษตรบ้านมหาสอน (บ้านสวนขวัญ)...
# กำลังประมวลผล index 8026: พิพิธภัณฑ์เหมืองลิกไนท์ กระบี่...
# กำลังประมวลผล index 8027: โฮมสเตย์เชิงอนุรักษ์วัฒนธรรมบ้านเชียง...
# กำลังประมวลผล index 8028: ตลาดน้ำคลองจินดา...
# กำลังประมวลผล index 8029: สวนมังคุดไทย...
# กำลังประมวลผล index 8030: ศูนย์พัฒนาขยายงานจักสานไม้ไผ่...
# กำลังประมวลผล index 8031: ศาลเจ้าพ่อเทพารักษ์ เจ้าแม่ทับทิม...
# กำลังประมวลผล index 8032: วัดประโชติการาม...
# กำลังประมวลผล index 8033: วัดเจ้าขาว...
# กำลังประมวลผล index 8034: เขาสวรรค์หล่น...
# กำลังประมวลผล index 8035: น้ำตกเขาพระนารายณ์...
# กำลังประมวลผล index 8036: วัดอัมพุวราราม...
# กำลังประมวลผล index 8037: ชุมชนบ้านเกาะกลาง...
# กำลังประมวลผล index 8038: พิพิธภัณฑ์ธรรมเจดีย์ พระธรรมวิสุทธิมงคล (หลวงตาพระมหาบัว ญาณสัมปันโน)...
# กำลังประมวลผล index 8039: ศูนย์วัฒนธรรมไทย จีน อุดรธานี...
# กำลังประมวลผล index 8040: ตลาดชุมชนคนยายชา...
# กำลังประมวลผล index 8041: ทูบ เทรค วอเตอร์ ปาร์ค...
# กำลังประมวลผล index 8042: ศูนย์ศึกษาธรรมชาติและสัตว์ป่าเขาพระแทว...
# กำลังประมวลผล index 8043: โรงบ่มปัว คาเฟ่ แอนด์ อีทเทอรี่ ...
# กำลังประมวลผล index 8044: ท็อปกอล์ฟ...
# กำลังประมวลผล index 8045: ทะเลหมอกเขาศูนย์...
# กำลังประมวลผล index 8046: ทะเลหมอกเขาจังโหลน...
# กำลังประมวลผล index 8047: คลองปากประ...
# กำลังประมวลผล index 8048: ศูนย์วัฒนธรรมอำเภอบางพลี...
# กำลังประมวลผล index 8049: หาดง่ามโข่...
# กำลังประมวลผล index 8050: สวนดอกไม้ป้านกเอี้ยง...
# กำลังประมวลผล index 8051: สมหวังที่วังยาง...
# กำลังประมวลผล index 8052: วัดพระนางสร้าง...
# กำลังประมวลผล index 8053: วัดม่วงโกมารภัจจ์...
# กำลังประมวลผล index 8054: เขื่อนทดน้ำบางปะกง...
# กำลังประมวลผล index 8055: เขาขนาบน้ำ...
# กำลังประมวลผล index 8056: หาดถ้ำพระนาง...
# กำลังประมวลผล index 8057: แหลมยามู...
# กำลังประมวลผล index 8058: วัดเชตุพน ...
# กำลังประมวลผล index 8059: หมู่บ้านนาตีน...
# กำลังประมวลผล index 8060: โฮมสเตย์บ้านวังน้ำมอก...
# กำลังประมวลผล index 8061: วัดเกาะกระทิง...
# กำลังประมวลผล index 8062: วิหารพระโพธิสัตว์กวนอิมทุ่งพิชัย...
# กำลังประมวลผล index 8063: ถนนคนเดินชุมชนริมคลองวัดพระงาม ทวารวดีศรีนครปฐม...
# กำลังประมวลผล index 8064: วัดกร่าง จ.ปทุมธานี(หลวงพ่อนรสิงห์)...
# กำลังประมวลผล index 8065: หาดพันทรี...
# กำลังประมวลผล index 8066: ฟาร์มแพะหลังเขื่อนปราณบุรี@ประจวบคีรีขันธ์...
# กำลังประมวลผล index 8067: คลองปากปิด ...
# กำลังประมวลผล index 8068: สินมานะฟาร์มสเตย์...
# กำลังประมวลผล index 8069: วัดนันตาราม...
# กำลังประมวลผล index 8070: เขตรักษาพันธุ์สัตว์ป่าแม่น้ำภาชี...
# กำลังประมวลผล index 8071: เกาะพีพีเล...
# กำลังประมวลผล index 8072: น้ำตกหินเพิง...
# กำลังประมวลผล index 8073: บ่อเกลือพันปี...
# กำลังประมวลผล index 8074: บาหลี น่าน...
# กำลังประมวลผล index 8075: โคกหนองนาแสนชื่น...
# กำลังประมวลผล index 8076: วัดบางน้ำผึ้งนอก ...
# กำลังประมวลผล index 8077: วัดท่าปุยตก...
# กำลังประมวลผล index 8078: น้ำตกอ่างเบง...
# กำลังประมวลผล index 8079: พันธุ์ทิพย์ ไลฟ์สไตล์ ฮับ   เชียงใหม่...
# กำลังประมวลผล index 8081: พิพิธภัณฑ์สถานคุ้มเจ้าเมืองหนองคาย  ...
# กำลังประมวลผล index 8082: พิพิธภัณฑ์เมืองหนองคาย...
# กำลังประมวลผล index 8083: วัดมะนาว...
# กำลังประมวลผล index 8084: บ้านพระยาวิชิตสงคราม  ...
# กำลังประมวลผล index 8085: น้ำพุร้อนแม่ขะจาน...
# กำลังประมวลผล index 8086: หาดนางกวัก...
# กำลังประมวลผล index 8087: เกาะตะเภาน้อย...
# กำลังประมวลผล index 8088: ทะเลแหวก...
# กำลังประมวลผล index 8089: เกาะกะทะ...
# กำลังประมวลผล index 8090: เกาะรังใหญ่...
# กำลังประมวลผล index 8091: ภูชมดาว  ...
# กำลังประมวลผล index 8092: วัดสระแก้ว...
# กำลังประมวลผล index 8093: วัดโบสถ์ หลวงปู่เทียน...
# กำลังประมวลผล index 8094: หาดทรายสะแกงาม...
# กำลังประมวลผล index 8095: สวนลุงหมง...
# กำลังประมวลผล index 8096: สนามยิงธนู...
# กำลังประมวลผล index 8097: โค้ง I LOVE U...
# กำลังประมวลผล index 8098: บียอนด์ สกายวอร์ค นางชี...
# กำลังประมวลผล index 8099: ตลาดริมยม 2437...
# กำลังประมวลผล index 8100: ชุมชนบ่อหินฟาร์มสเตย์...
# กำลังประมวลผล index 8101: อ่างเก็บน้ำคลองมดแดง...
# กำลังประมวลผล index 8102: ชุมชนท่องเที่ยวบ้านเขาหลัก...
# กำลังประมวลผล index 8103: สะพานช่อแล...
# กำลังประมวลผล index 8104: Inthanon Mountain Camping...
# กำลังประมวลผล index 8105: ฟลามิงโก้ บลูมมิ่ง บีช...
# กำลังประมวลผล index 8106: แม่ปั๋ง แคมป์ปิ้ง...
# กำลังประมวลผล index 8107: เป้อ หละ เหม้อ...
# กำลังประมวลผล index 8108: ลิตเติ้ลโซล...
# กำลังประมวลผล index 8109: บ้านม้าท่าน้ำ...
# กำลังประมวลผล index 8110: วัดถ้ำเสือน้อย...
# กำลังประมวลผล index 8111: อ่าววงเดือน...
# กำลังประมวลผล index 8112: เกาะหนู เกาะแมว...
# กำลังประมวลผล index 8113: อ่างเก็บน้ำกระทูน...
# กำลังประมวลผล index 8114: อุทยานแห่งชาติออบขาน...
# กำลังประมวลผล index 8115: วัดเด่นสะหลีศรีเมืองแกน...
# กำลังประมวลผล index 8116: พระธาตุบ้านเดียม...
# กำลังประมวลผล index 8117: ศาลเจ้าแม่ทับทิม...
# กำลังประมวลผล index 8118: ถ้ำเสือน้อย...
# กำลังประมวลผล index 8119: เขากาโรส...
# กำลังประมวลผล index 8120: สะพานสราญวิถี...
# กำลังประมวลผล index 8124: วัดทรงธรรมกัลยาณี...
# กำลังประมวลผล index 8125: สวนสิรินธราพฤกษาพรรณ (สวนเฉลิมพระเกียรติฯ 80 พรรษา)...
# กำลังประมวลผล index 8126: วัดโคกจ้าหล่า...
# กำลังประมวลผล index 8127: Cypress Lanes...
# กำลังประมวลผล index 8128: ล่องแก่ง เชียงใหม่ ธนาแอดเวนเจอร์...
# กำลังประมวลผล index 8129: Thingamajiggy Coffee Roaster...
# กำลังประมวลผล index 8130: ดอยหมื่นหมาก...
# กำลังประมวลผล index 8131: ตลาดโบราณบางพลี...
# กำลังประมวลผล index 8132: วงเวียนโปงลาง ...
# กำลังประมวลผล index 8133: อ่าวโล๊ะซามะ...
# กำลังประมวลผล index 8134: สวนเจ้าฟ้า...
# กำลังประมวลผล index 8135: พระพุทธไสยาสน์...
# กำลังประมวลผล index 8136: บ่อน้ำร้อนหาดยาย...
# กำลังประมวลผล index 8137: วัดน้อยหลวงพ่อเนียม...
# กำลังประมวลผล index 8138: ถนนคนเดินหนองคาย...
# กำลังประมวลผล index 8139: เกาะแรด...
# กำลังประมวลผล index 8140: ศูนย์หัตถกรรมกระจูดวรรณี...
# กำลังประมวลผล index 8141: น้ำตกห้วยตึงเฒ่า (ตาดมุก)...
# กำลังประมวลผล index 8142: เจดีย์อิสรภาพ...
# กำลังประมวลผล index 8143: หมู่บ้านท่องเที่ยวชาวดอย (ม้ง) เล่าลือ...
# กำลังประมวลผล index 8144: น้ำตกห้วยหอย...
# กำลังประมวลผล index 8147: วัดถ้ำจันทร์...
# กำลังประมวลผล index 8148: อ่างเก็บน้ำช่องลม เขาล้าน...
# กำลังประมวลผล index 8149: สวนส้มเขียวหวานโชกุน...
# กำลังประมวลผล index 8150: Songkhla Flower Farm...
# กำลังประมวลผล index 8151: อุทยานแห่งชาติลำน้ำกระบุรี...
# กำลังประมวลผล index 8152: ตลาดน้ำบางคูเวียง...
# กำลังประมวลผล index 8153: อุทยานประวัติศาสตร์เมืองสิงห์...
# กำลังประมวลผล index 8154: สวนพฤกษศาสตร์ป่าชายเลนนานาชาติ ร.9...
# กำลังประมวลผล index 8155: ตลาดปลาระยอง หาดแสงจันทร์...
# กำลังประมวลผล index 8156: บ้านเขียวขุนพิทักษ์บริหาร...
# กำลังประมวลผล index 8157: วัดกลางคลองวัฒนาราม...
# กำลังประมวลผล index 8158: ตลาดทะเลไทย...
# กำลังประมวลผล index 8159: น้ำตกธารโบกขรณี...
# กำลังประมวลผล index 8160: อ่าวมาหยา...
# กำลังประมวลผล index 8161: ไร่ปางวัว...
# กำลังประมวลผล index 8162: ถ้ำนางสิบสอง...
# กำลังประมวลผล index 8163: อ่างเก็บน้ำห้วยแม่ลำพัน...
# กำลังประมวลผล index 8164: Jungle Adventure Park...
# กำลังประมวลผล index 8165: ลานกางเต๊นท์เอื้องเงิน...
# กำลังประมวลผล index 8167: น่านปางช้าง...
# กำลังประมวลผล index 8168: กองพลทหารราบที่ 2 รักษาพระองค์...
# กำลังประมวลผล index 8169: สะพานสายรุ้ง และสะพานชมวิวชายทะเลกาหลง...
# กำลังประมวลผล index 8170: เกาะดอนโพธิ์...
# กำลังประมวลผล index 8171: อชิ คาเฟ่ สวนคุณประยูร...
# กำลังประมวลผล index 8172: ศาลเทพารักษ์...
# กำลังประมวลผล index 8173: ถนนคนเดินหลาดใน...
# กำลังประมวลผล index 8174: สวนสาธารณะธารา...
# กำลังประมวลผล index 8175: สมาภรณ์ การ์เด้น...
# กำลังประมวลผล index 8176: เกาะรอกใน...
# กำลังประมวลผล index 8177: สวนสัตว์หัวหิน...
# กำลังประมวลผล index 8178: โบราณสถานเตาโอ่งอ่าง...
# กำลังประมวลผล index 8179: ศูนย์เรียนรู้เศรษฐกิจพอเพียงด้านวนเกษตร...
# กำลังประมวลผล index 8180: สวนเทิดพระเกียรติ...
# กำลังประมวลผล index 8181: เฮง สเตชั่น...
# กำลังประมวลผล index 8182: เนเจอร์ ทอล์ค...
# กำลังประมวลผล index 8183: บ้านคลองนาเกลือ...
# กำลังประมวลผล index 8184: กิโล9 พัทยาเมืองฮอด...
# กำลังประมวลผล index 8185: น้ำตกวังม่วง...
# กำลังประมวลผล index 8186: น้ำตกเหมืองทวด   อุทยานแห่งชาติใต้ร่มเย็น...
# กำลังประมวลผล index 8187: บ้านท่าคา...
# กำลังประมวลผล index 8188: บ้านน้ำเลนคาเฟ่ มินิซู แอนด์ โฮมสเตย์...
# กำลังประมวลผล index 8189: สวนส้มโอไทยทวี...
# กำลังประมวลผล index 8190: บ้านข้าวหอม ฟาร์มสเตย์...
# กำลังประมวลผล index 8191: วัดโฆสิตาราม (วัดบ้านแค)...
# กำลังประมวลผล index 8192: สะพานเฉลิมพระเกียรติ 80 พรรษา ฯ...
# กำลังประมวลผล index 8193: หลาดริมคลองหัวไทร...
# กำลังประมวลผล index 8194: ยิ่งยงสวนดอกไม้...
# กำลังประมวลผล index 8195: WTF Coffee Camp ...
# กำลังประมวลผล index 8196: วัดญาณเวศกวัน...
# กำลังประมวลผล index 8197: วัดดอนยายหอม...
# กำลังประมวลผล index 8198: ปราสาทปลายบัด 2...
# กำลังประมวลผล index 8199: Pa Pae Meditation Retreat ...
# กำลังประมวลผล index 8202: พันโขดแสนไคร้...
# กำลังประมวลผล index 8203: สกายวอร์ควัดระธาตุดอยสะเก็ด...
# กำลังประมวลผล index 8204: วัดไก่เตี้ย...
# กำลังประมวลผล index 8205: สระมรกต...
# กำลังประมวลผล index 8206: ถ้ำตั๊กแตน...
# กำลังประมวลผล index 8207: อ่าวป่าหล่าย...
# กำลังประมวลผล index 8208: วัดจุกเฌอ...
# กำลังประมวลผล index 8209:  อุทยานพระพิฆเนศองค์ยืน...
# กำลังประมวลผล index 8210: วัดท่าปุยออก...
# กำลังประมวลผล index 8211: Lighthouse Maenam...
# กำลังประมวลผล index 8212: วัดวาลุการาม...
# กำลังประมวลผล index 8213: วิสาหกิจชุมชนเกษตรคนหันคา จังหวัดชัยนาท(สวนศรีบุญนาค)...
# กำลังประมวลผล index 8214: ชุมชนศรีรายา (ชุมชนเมืองเก่าเกาะลันตา)...
# กำลังประมวลผล index 8215: ถ้ำคลัง...
# กำลังประมวลผล index 8216: แหลมตง...
# กำลังประมวลผล index 8217: เกาะห้อง...
# กำลังประมวลผล index 8218: วัดปากน้ำโจ้โล้...
# กำลังประมวลผล index 8219: ชุมชนท่องเที่ยวบ้านภูผาเพชร...
# กำลังประมวลผล index 8220: วัดพระงาม...
# กำลังประมวลผล index 8221: บ้านสวนปรีดา...
# กำลังประมวลผล index 8222: อ่างเก็บน้ำคลองดินแดง...
# กำลังประมวลผล index 8224: ดอยค้ำฟ้า...
# กำลังประมวลผล index 8225: พิพิธภัณฑสถานวัดคลองท่อม...
# กำลังประมวลผล index 8226: พิพิธภัณฑ์บ้านก๋ง...
# กำลังประมวลผล index 8227: วัดเทพนิมิตร...
# กำลังประมวลผล index 8228: เขาล้อมหมวก...
# กำลังประมวลผล index 8229: ขี่รถ ATV ในกรุงเทพ...
# กำลังประมวลผล index 8230: สวนน้ำ อิมปาร์ค ห้างอิมพีเรียล เวิลด์ สำโรง ...
# กำลังประมวลผล index 8231: วัดทุ่งเคล็ด...
# กำลังประมวลผล index 8232: อุทยานแห่งชาติเขาสก...
# กำลังประมวลผล index 8233: วัดไตรสามัคคี...
# กำลังประมวลผล index 8234: พระธาตุศรีสุราษฎร์...
# กำลังประมวลผล index 8235: วัดเจริญสุขารามวรวิหาร...
# กำลังประมวลผล index 8237: วัดจอมธรรม...
# กำลังประมวลผล index 8239: น้ำพุร้อนโป่งเดือด...
# กำลังประมวลผล index 8240: ผาจูบกัน...
# กำลังประมวลผล index 8241: อ่างกา...
#
# ประมวลผลเสร็จสิ้น! บันทึกผลลัพธ์ลงในไฟล์ 'places_results.csv'
#
# ตัวอย่างข้อมูลจากไฟล์ผลลัพธ์:
#    original_index            match_result  score  \
# 0               0  ไม่แน่ใจ (ต้องตรวจซ้ำ)      8
# 1               1                  ไม่ตรง      5
# 2               3                     ตรง     11
# 3               4  ไม่แน่ใจ (ต้องตรวจซ้ำ)      8
# 4               5                     ตรง     11
#
#                                        score_reasons  distance_m  \
# 0  distance<200m (+5), name_sim>0.6 (+1), distric...      126.36
# 1  distance<5km (+2), name_sim>0.6 (+1), district...     1786.19
# 2  distance<200m (+5), name_sim>0.92 (+4), distri...        1.46
# 3  distance<200m (+5), name_sim>0.6 (+1), distric...        8.12
# 4  distance<200m (+5), name_sim>0.92 (+4), distri...       12.67
#
#                                            textQuery       expected_type  \
# 0           เสาหินบะซอลต์ นางรอง บุรีรัมย์ ประเทศไทย  tourist_attraction
# 1       อ่างเก็บน้ำลำพอก ศีขรภูมิ สุรินทร์ ประเทศไทย  tourist_attraction
# 2  กลุ่มสตรีทอผ้าบ้านท่ากระจาย ท่าชนะ สุราษฎร์ธาน...  tourist_attraction
# 3    องค์ศรีสุขคเณศ เมืองอุดรธานี อุดรธานี ประเทศไทย  tourist_attraction
# 4       พัทยา ดอลฟินาเรียม บางละมุง ชลบุรี ประเทศไทย  tourist_attraction
#
#                             api_name  \
# 0      เสาหินบะซอลต์ภูเขาไฟบุรีรัมย์
# 1  อ่างเก็บน้ำห้วยลำพอก (อ.ศีขรภูมิ)
# 2        กลุ่มสตรีทอผ้าบ้านท่ากระจาย
# 3             องค์ศรีสุขเณศ อุดรธานี
# 4                 พัทยา ดอลฟินาเรียม
#
#                                 api_formattedAddress  \
# 0  HRM4+5H5 บ้านโคกมะค่าโหรน ตำบล สะเดา อำเภอนางร...
# 1    WVM3+C29 ตำบล ยาง อำเภอ ศีขรภูมิ สุรินทร์ 32110
# 2  บ้านเลขที่ 131 หมู่ที่ 1 บ้านท่ากระจาย, ตำบลท่...
# 3  25 ถ. โพศรี ตำบล บ้านเลื่อม อำเภอเมืองอุดรธานี...
# 4        555 5 เมืองพัทยา อำเภอบางละมุง ชลบุรี 20150
#
#                                         api_location  api_rating  \
# 0   {'latitude': 14.582883, 'longitude': 102.806497}         4.1
# 1  {'latitude': 14.933548400000001, 'longitude': ...         4.4
# 2  {'latitude': 9.590331299999999, 'longitude': 9...         5.0
# 3  {'latitude': 17.4114213, 'longitude': 102.7806...         4.9
# 4  {'latitude': 12.9509367, 'longitude': 100.9365...         4.7
#
#    api_userRatingCount                                          api_types  \
# 0                 61.0             park, point_of_interest, establishment
# 1                 41.0  tourist_attraction, point_of_interest, establi...
# 2                  2.0       wholesaler, point_of_interest, establishment
# 3                 10.0  place_of_worship, point_of_interest, establish...
# 4               4240.0  tourist_attraction, aquarium, point_of_interes...
#
#                    api_placeId  \
# 0  ChIJoTTUOYwtGjERMkF-YwM5fR8
# 1  ChIJQxIzgedBFzER2EPT62xI8iA
# 2  ChIJs6H3FhOdVjARqmVmgZEBjFA
# 3  ChIJsxKc5UmdIzERq_9q200D3go
# 4  ChIJ-1r7GDG_AjEROPhozW94Nxs
#
#                                              api_URI  \
# 0  https://maps.google.com/?cid=22690324739815017...
# 1  https://maps.google.com/?cid=23740395862278317...
# 2  https://maps.google.com/?cid=58040157442265839...
# 3  https://maps.google.com/?cid=78306701813763268...
# 4  https://maps.google.com/?cid=19611685843260518...
#
#                                      original_detail
# 0  เสาหินบะซอลล์ภูเขาไฟ หรือ แกรนด์แคนยอนบุรีรัมย...
# 1      อ่างเก็บน้ำลำพอก เป็นสถานที่กักเก็บน้ำเพื่...
# 2    ชุมชมดั้งเดิมนี้ ประกอบอาชีพหลักคือประมงและท...
# 3   องค์ศรีสุขคเณศ  พระพิฆเนศ ปางนาคปรก เป็น  พระ...
# 4  การแสดงโลมา สัตว์เลี้ยงลูกด้วยนมที่ฉลาด แสนรู้...
